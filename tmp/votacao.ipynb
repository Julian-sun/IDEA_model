# %%
import pandas as pd
import numpy as np
from scipy.stats import nbinom
from pathlib import Path


import matplotlib.pyplot as plt

# %%
# Read data

mun_new = list(Path('/opt/storage/refined/aesop/visualization/')
               .glob('aesop_*_mun_new.parquet'))

aesop_mun_new = max(mun_new, key=lambda x: x.stat().st_ctime)

df = pd.read_parquet(aesop_mun_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       1 # Read data
#       3 mun_new = list(Path('/opt/storage/refined/aesop/visualization/')
#       4                .glob('aesop_*_mun_new.parquet'))
# ----> 6 aesop_mun_new = max(mun_new, key=lambda x: x.stat().st_ctime)
#       8 df = pd.read_parquet(aesop_mun_new)
#
# ValueError: max() arg is an empty sequence

# %%
mun_new
# Out:
# []

# %%
df
# Out:
#     epidemi_cal_start epidemi_cal_end year_week_ts year_week  epiyear  \
# 0          2020-12-27      2021-01-02   2020-12-28   2020-53     2020
# 1          2024-12-15      2024-12-21   2024-12-16   2024-51     2024
# 2          2021-09-26      2021-10-02   2021-09-27   2021-39     2021
# 3          2023-02-19      2023-02-25   2023-02-20   2023-08     2023
# 4          2023-01-15      2023-01-21   2023-01-16   2023-03     2023
# ..                ...             ...          ...       ...      ...
# 443        2024-09-01      2024-09-07   2024-09-02   2024-36     2024
# 444        2023-11-19      2023-11-25   2023-11-20   2023-47     2023
# 445        2021-10-10      2021-10-16   2021-10-11   2021-41     2021
# 446        2020-10-11      2020-10-17   2020-10-12   2020-42     2020
# 447        2018-10-07      2018-10-13   2018-10-08   2018-41     2018
#
#      epiweek  atend_ivas  atend_arbov  atend_totais  sinal_evi_ivas  \
# 0         53      107206         1024        763983              51
# 1         51      331258        18166       6403834             379
# 2         39      383559         4078       6838467            1614
# 3          8      253182        24738       4532145             515
# 4          3      237728        17650       8482304            1091
# ..       ...         ...          ...           ...             ...
# 443       36      614225        20028      10621261             711
# 444       47      342564        11966       9518401            1037
# 445       41      254782         2762       4833200             382
# 446       42      274925         3763       4829150             586
# 447       41      198462         2772       6263443             612
#
#      sinal_evi_arbov  sinal_ears_ivas  sinal_ears_arbov  sinal_mmaing_ivas  \
# 0                 58                0                 0                  0
# 1                213              215               608                223
# 2               1387                0                 0                  0
# 3                201              244                 0                  0
# 4               1949               97                 0                  0
# ..               ...              ...               ...                ...
# 443              443             1138               183                947
# 444             1136              294               341                101
# 445              385                0                 0                  0
# 446              515                0                 0                  0
# 447              619                0                 0                  0
#
#      sinal_mmaing_arbov  sinal_ens_ivas  sinal_ens_arbov  sinal_otc_ivas  \
# 0                     0              51               58               0
# 1                     0             192              104             186
# 2                     0            1614             1387               0
# 3                     0              64              201            4237
# 4                     0             351             1949            3807
# ..                  ...             ...              ...             ...
# 443                   0             756              120             327
# 444                   0             107               73            2503
# 445                   0             382              385               0
# 446                   0             586              515               0
# 447                   0             612              619               0
#
#      sinal_aesop_ivas
# 0                   0
# 1                 302
# 2                   0
# 3                4237
# 4                3807
# ..                ...
# 443               967
# 444              2554
# 445                 0
# 446                 0
# 447                 0
#
# [448 rows x 19 columns]
