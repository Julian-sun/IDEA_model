# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
muni = pd.read_csv('/Users/julianeoliveira/Documents/Projects/AESOP/AESOP datalake/DTB_BRASIL_MUNICIPIO.csv',sep=';')

muni = muni[['UF', 'Nome_UF', 'Mesorregião Geográfica', 'Nome_Mesorregião',
       'Microrregião Geográfica', 'Nome_Microrregião', 'Município',
       'Código Município Completo', 'Nome_Município']]

muni = muni.assign(co_ibge6 = muni['Código Município Completo'].astype(str).str[0:6])

muni.co_ibge6 = muni.co_ibge6.astype(int)

dta = pd.read_csv('/Users/julianeoliveira/Downloads/union_paths.csv')


hubs = pd.read_csv('/Users/julianeoliveira/Downloads/Reproducibility results_paper2/data/lists_of_hubs.csv')
hubs = hubs[['Nome_UF', 'co_ibge', 'Nome_Município', 'hub_ind_proxi',
       'hub_ind_intermed', 'hub_inter']]

limi = pd.read_csv('/Users/julianeoliveira/Downloads/municipios_limitrofes_ibge.csv')


# Read the Adjacent matrix
link0 = '/Users/julianeoliveira/Downloads/adjacency_matrix_correct.parquet'

matrix = pd.read_parquet(link0, engine='pyarrow')

link_muni_vertice = pd.DataFrame(matrix.columns, columns=['muni'])

df_np = matrix.to_numpy()

# %%
df = pd.read_parquet('/Users/julianeoliveira/Downloads/aesop_2025_10_01_mun_withNewEnsIvas.parquet')

df = df[df.epiyear >= 2022]

# %%
def get_mname(n):
    
    m = link_muni_vertice.iloc[n]['muni']
    set_muni = muni[muni['Código Município Completo'] == m].reset_index()
    return [set_muni.iloc[0]['Nome_Município'],set_muni.iloc[0]['Nome_UF'],m]
   
def get_mnumber(name):
    muni[muni['Nome_Município'] == name]
    
    co_mu = muni[muni['Nome_Município'] == name].reset_index()['Código Município Completo'][0]
    muni_number = link_muni_vertice[link_muni_vertice['muni'] == co_mu]['muni'].index.tolist()[0]
    return [muni_number, co_mu]

def col_name(dtf,col):
    lst = []
    for value in col:
        muni_name = get_mname(value)[0]
        uf_muni = get_mname(value)[1]
        cod_ibge_muni = get_mname(value)[2]
    
        lst.append([muni_name,uf_muni,cod_ibge_muni])
    
    dta = pd.DataFrame(lst, columns=['muni_name','uf_muni','cod_ibge_muni'])
    
    dtf = dtf.assign(muni_name = dta.muni_name)
    dtf = dtf.assign(uf_muni = dta.uf_muni)
    dtf = dtf.assign(cod_ibge_muni = dta.cod_ibge_muni)
    
    return dtf

# %%
def conditional_spread_prob(df, index_city, neighbours, k=1):
    """
    Compute P(neighbour has >=1 warning within k weeks starting at same week as index warning),
    aggregated over all index warnings observed in df.
    
    Parameters
    ----------
    df : DataFrame (rows=cities indexed by code, cols=week labels)
    index_city : city code
    neighbours : list of neighbour city codes
    k : int, window size in weeks (k=0 means same week only; k=1 means same week or next week)
    """
    weeks = list(df.columns)
    n_weeks = len(weeks)
    
    # Find all weeks where index city has a warning (=1)
    index_weeks = [i for i,w in enumerate(weeks) if df.loc[index_city, w] == 1]
    if not index_weeks:
        return None
    
    # For each neighbour, count how many index-week events were followed by at least one warning
    results = []
    for n in neighbours:
        triggered = 0
        total = 0
        for iw in index_weeks:
            # define window [iw, iw + k] inclusive, but not beyond available weeks
            start = iw
            end = min(iw + k, n_weeks - 1)
            total += 1
            # check if neighbour has any 1 in that window
            window_weeks = weeks[start:end+1]
            if df.loc[n, window_weeks].sum() > 0:
                triggered += 1
        prob = triggered / total if total > 0 else np.nan
        results.append({'neighbour': n, 'triggered': triggered, 'total_index_events': total, 'P': prob})
    
    res_df = pd.DataFrame(results).set_index('neighbour')
    # Aggregate across neighbours: probability that *a random neighbour* is triggered
    agg_P = res_df['P'].mean()
    # Probability that at least one neighbour is triggered for each index event
    # compute per index event whether any neighbour had 1 in window, then average
    any_trigger_per_event = []
    for iw in index_weeks:
        start = iw
        end = min(iw + k, n_weeks - 1)
        window_weeks = weeks[start:end+1]
        # check across all neighbours for that index event
        any_trigger = (df.loc[neighbours, window_weeks].sum(axis=0).sum() > 0)
        any_trigger_per_event.append(1 if any_trigger else 0)
    prob_any_neighbour = np.mean(any_trigger_per_event)
    
    return res_df, agg_P, prob_any_neighbour, index_weeks

# %% [markdown]
# # Inicio

# %%
lst = ['sigla_uf','co_uf','nm_uf',
     'nm_municipio','co_ibge',  'co_ibge7',
     'epiyear','epiweek','epidemi_cal_start', 'year_week',
     'atend_totais','atend_ivas',
     'sinal_ens_ivas','sinal_otc_ivas','Aviso AESOP',
     'alerta_vizinho', 'aviso_vizinho','sinais_vizinhos',
      'sinal_ens_ivas_new']

dta = dta[['ori_muni_name','ori_uf_name', 'ori_co_ibge', 
           'des_muni_name', 'des_uf_name','des_co_ibge', 
           'path_correct', 'value','muni_1', 'muni_2', 'muni_3','ones']]

# %%
lst_results = []

# iterate through origin cities
for city in  df.co_ibge7.unique(): #df[df.nm_uf == 'Ceará'].co_ibge7.unique()
    
    print(f"Processing city: {city}")
    
    # --- Filter health data for the city ---
    set_muni = df[df.co_ibge7 == city].copy()

    # ⚠️ Skip if the origin city never had a warning
    if set_muni['Aviso AESOP'].sum() == 0:
        print(f"  → Skipped (no warning detected for city {city})")
        continue

    # --- Filter connected cities based on mobility data ---
    set_muni_mob = (
        dta[dta.ori_co_ibge == city]
        .groupby(['ori_muni_name', 'ori_uf_name', 'ori_co_ibge', 'muni_1'])[['ones', 'value']]
        .sum()
        .reset_index()
    )

    set_muni_mob = col_name(set_muni_mob, set_muni_mob.muni_1)
    set_muni_mob = set_muni_mob.assign(per=set_muni_mob.ones * 100 / set_muni_mob.ones.sum())

    # --- Build list of destination municipalities (neighbors) ---
    lst_des_muni = list(set_muni_mob.cod_ibge_muni.unique())

    # Add the origin city itself
    lst_des_muni.append(city)

    # Add bordering municipalities from adjacency table `limi`
    border_neigh = list(limi.loc[limi.codigo_ibge_municipio == city, 'codigo_ibge_vizinho'].unique())
    lst_des_muni.extend(border_neigh)

    # Remove duplicates and ensure integers
    lst_des_muni = list(set(map(int, lst_des_muni)))
    
    # ⚠️ Skip if the origin city is isolated in the network, no connections or nbordering cities
    if len(lst_des_muni) <= 1:
        print(f"  → Skipped (no network neighbours for city {city})")
        continue


    # --- Filter data for these cities ---
    data1 = df[df.co_ibge7.isin(lst_des_muni)][['co_ibge7', 'year_week', 'Aviso AESOP']].copy()

    # --- Pivot to wide format (city x week) ---
    table = pd.pivot_table(
        data1,
        values='Aviso AESOP',
        index='co_ibge7',
        columns='year_week',
        aggfunc='sum',
        fill_value=0
    )

    # Define index city and its neighbours
    index_city = city
    neighbours = [c for c in table.index if c != index_city]

    # --- Compute conditional spread probabilities ---
    outputs = {}
    for k in [0, 1, 2, 3, 4, 5]:
        res_df, avg_P, prob_any, index_weeks = conditional_spread_prob(table, index_city, neighbours, k=k)
        outputs[k] = {
            'per_neighbour': res_df,
            'avg_P_neighbour': avg_P,
            'P_any_neighbour': prob_any,
            'index_weeks': index_weeks
        }

    # --- Format results for this origin city ---
    lst_res = []
    for k, out in outputs.items():
        res_data = out['per_neighbour'].reset_index().assign(
            average_neighbour_level_probability=out['avg_P_neighbour'],
            prob_at_least_one_neighbour_triggered=out['P_any_neighbour'],
            k=k,
            origin_city=city
        )
        lst_res.append(res_data)

    final = pd.concat(lst_res, ignore_index=True)
    lst_results.append(final)
# Out:
# Processing city: 1100015
# Processing city: 1100023
# Processing city: 1100031
# Processing city: 1100049
# Processing city: 1100056
# Processing city: 1100064
# Processing city: 1100072
# Processing city: 1100080
# Processing city: 1100098
# Processing city: 1100106
# Processing city: 1100114
# Processing city: 1100122
# Processing city: 1100130
# Processing city: 1100148
# Processing city: 1100155
# Processing city: 1100189
# Processing city: 1100205
# Processing city: 1100254
# Processing city: 1100262
# Processing city: 1100288
# Processing city: 1100296
# Processing city: 1100304
# Processing city: 1100320
# Processing city: 1100338
# Processing city: 1100346
# Processing city: 1100379
# Processing city: 1100403
# Processing city: 1100452
# Processing city: 1100502
# Processing city: 1100601
# Processing city: 1100700
# Processing city: 1100809
# Processing city: 1100908
# Processing city: 1100924
# Processing city: 1100940
# Processing city: 1101005
# Processing city: 1101104
# Processing city: 1101203
# Processing city: 1101302
# Processing city: 1101401
# Processing city: 1101435
# Processing city: 1101450
# Processing city: 1101468
# Processing city: 1101476
# Processing city: 1101484
# Processing city: 1101492
# Processing city: 1101500
# Processing city: 1101559
# Processing city: 1101609
# Processing city: 1101708
# Processing city: 1101757
# Processing city: 1101807
# Processing city: 1200013
# Processing city: 1200054
# Processing city: 1200104
# Processing city: 1200138
# Processing city: 1200179
# Processing city: 1200203
# Processing city: 1200252
# Processing city: 1200302
# Processing city: 1200328
# Processing city: 1200336
# Processing city: 1200344
# Processing city: 1200351
# Processing city: 1200385
# Processing city: 1200393
# Processing city: 1200401
# Processing city: 1200427
# Processing city: 1200435
# Processing city: 1200450
# Processing city: 1200500
# Processing city: 1200609
# Processing city: 1200708
# Processing city: 1200807
# Processing city: 1300029
# Processing city: 1300060
# Processing city: 1300086
# Processing city: 1300102
# Processing city: 1300144
# Processing city: 1300201
# Processing city: 1300300
# Processing city: 1300409
# Processing city: 1300508
# Processing city: 1300607
# Processing city: 1300631
# Processing city: 1300680
# Processing city: 1300706
# Processing city: 1300805
# Processing city: 1300839
# Processing city: 1300904
# Processing city: 1301001
# Processing city: 1301100
# Processing city: 1301159
# Processing city: 1301209
# Processing city: 1301308
# Processing city: 1301407
# Processing city: 1301506
# Processing city: 1301605
# Processing city: 1301654
# Processing city: 1301704
# Processing city: 1301803
# Processing city: 1301852
# Processing city: 1301902
# Processing city: 1301951
# Processing city: 1302009
# Processing city: 1302108
# Processing city: 1302207
# Processing city: 1302306
# Processing city: 1302405
# Processing city: 1302504
# Processing city: 1302553
# Processing city: 1302702
# Processing city: 1302801
# Processing city: 1302900
# Processing city: 1303007
# Processing city: 1303106
# Processing city: 1303205
# Processing city: 1303304
# Processing city: 1303403
# Processing city: 1303502
# Processing city: 1303536
# Processing city: 1303569
# Processing city: 1303601
# Processing city: 1303700
# Processing city: 1303809
# Processing city: 1303908
# Processing city: 1303957
# Processing city: 1304005
# Processing city: 1304062
# Processing city: 1304104
# Processing city: 1304203
# Processing city: 1304237
# Processing city: 1304260
# Processing city: 1304302
# Processing city: 1304401
# Processing city: 1400027
# Processing city: 1400050
# Processing city: 1400100
# Processing city: 1400159
# Processing city: 1400175
# Processing city: 1400209
# Processing city: 1400233
# Processing city: 1400282
# Processing city: 1400308
# Processing city: 1400407
# Processing city: 1400456
# Processing city: 1400472
# Processing city: 1400506
# Processing city: 1400605
# Processing city: 1400704
# Processing city: 1500107
# Processing city: 1500131
# Processing city: 1500206
# Processing city: 1500305
# Processing city: 1500347
# Processing city: 1500404
# Processing city: 1500503
# Processing city: 1500602
# Processing city: 1500701
# Processing city: 1500800
# Processing city: 1500859
# Processing city: 1500909
# Processing city: 1500958
# Processing city: 1501006
# Processing city: 1501105
# Processing city: 1501204
# Processing city: 1501253
# Processing city: 1501303
# Processing city: 1501402
# Processing city: 1501451
# Processing city: 1501501
# Processing city: 1501576
# Processing city: 1501600
# Processing city: 1501709
# Processing city: 1501725
# Processing city: 1501758
# Processing city: 1501782
# Processing city: 1501808
# Processing city: 1501907
# Processing city: 1501956
# Processing city: 1502004
# Processing city: 1502103
# Processing city: 1502152
# Processing city: 1502202
# Processing city: 1502301
# Processing city: 1502400
# Processing city: 1502509
# Processing city: 1502608
# Processing city: 1502707
# Processing city: 1502756
# Processing city: 1502764
# Processing city: 1502772
# Processing city: 1502806
# Processing city: 1502855
# Processing city: 1502905
# Processing city: 1502939
# Processing city: 1502954
# Processing city: 1503002
# Processing city: 1503044
# Processing city: 1503077
# Processing city: 1503093
# Processing city: 1503101
# Processing city: 1503200
# Processing city: 1503309
# Processing city: 1503408
# Processing city: 1503457
# Processing city: 1503507
# Processing city: 1503606
# Processing city: 1503705
# Processing city: 1503754
# Processing city: 1503804
# Processing city: 1503903
# Processing city: 1504000
# Processing city: 1504059
# Processing city: 1504109
# Processing city: 1504208
# Processing city: 1504307
# Processing city: 1504406
# Processing city: 1504422
# Processing city: 1504455
# Processing city: 1504505
# Processing city: 1504604
# Processing city: 1504703
# Processing city: 1504752
# Processing city: 1504802
# Processing city: 1504901
# Processing city: 1504950
# Processing city: 1504976
# Processing city: 1505007
# Processing city: 1505031
# Processing city: 1505064
# Processing city: 1505106
# Processing city: 1505205
# Processing city: 1505304
# Processing city: 1505403
# Processing city: 1505437
# Processing city: 1505486
# Processing city: 1505494
# Processing city: 1505502
# Processing city: 1505536
# Processing city: 1505551
# Processing city: 1505601
# Processing city: 1505635
# Processing city: 1505650
# Processing city: 1505700
# Processing city: 1505809
# Processing city: 1505908
# Processing city: 1506005
# Processing city: 1506104
# Processing city: 1506112
# Processing city: 1506138
# Processing city: 1506161
# Processing city: 1506187
# Processing city: 1506195
# Processing city: 1506203
# Processing city: 1506302
# Processing city: 1506351
# Processing city: 1506401
# Processing city: 1506500
# Processing city: 1506559
# Processing city: 1506583
# Processing city: 1506609
# Processing city: 1506708
# Processing city: 1506807
# Processing city: 1506906
# Processing city: 1507003
# Processing city: 1507102
# Processing city: 1507151
# Processing city: 1507201
# Processing city: 1507300
# Processing city: 1507409
# Processing city: 1507458
# Processing city: 1507466
# Processing city: 1507474
# Processing city: 1507508
# Processing city: 1507607
# Processing city: 1507706
# Processing city: 1507755
# Processing city: 1507805
# Processing city: 1507904
# Processing city: 1507953
# Processing city: 1507961
# Processing city: 1507979
# Processing city: 1508001
# Processing city: 1508035
# Processing city: 1508050
# Processing city: 1508084
# Processing city: 1508100
# Processing city: 1508126
# Processing city: 1508159
# Processing city: 1508209
# Processing city: 1508308
# Processing city: 1508357
# Processing city: 1508407
# Processing city: 1600055
# Processing city: 1600105
# Processing city: 1600154
# Processing city: 1600204
# Processing city: 1600212
# Processing city: 1600238
# Processing city: 1600253
# Processing city: 1600279
# Processing city: 1600303
# Processing city: 1600402
# Processing city: 1600501
# Processing city: 1600535
# Processing city: 1600550
#   → Skipped (no warning detected for city 1600550)
# Processing city: 1600600
# Processing city: 1600709
# Processing city: 1600808
# Processing city: 1700251
# Processing city: 1700301
# Processing city: 1700350
# Processing city: 1700400
# Processing city: 1700707
# Processing city: 1701002
# Processing city: 1701051
# Processing city: 1701101
# Processing city: 1701309
# Processing city: 1701903
# Processing city: 1702000
# Processing city: 1702109
# Processing city: 1702158
# Processing city: 1702208
# Processing city: 1702307
# Processing city: 1702406
# Processing city: 1702554
# Processing city: 1702703
# Processing city: 1702901
# Processing city: 1703008
# Processing city: 1703057
# Processing city: 1703073
# Processing city: 1703107
# Processing city: 1703206
# Processing city: 1703305
# Processing city: 1703602
# Processing city: 1703701
# Processing city: 1703800
# Processing city: 1703826
# Processing city: 1703842
# Processing city: 1703867
# Processing city: 1703883
# Processing city: 1703891
# Processing city: 1703909
# Processing city: 1704105
# Processing city: 1704600
# Processing city: 1705102
# Processing city: 1705508
# Processing city: 1705557
# Processing city: 1705607
# Processing city: 1706001
# Processing city: 1706100
# Processing city: 1706258
# Processing city: 1706506
# Processing city: 1707009
# Processing city: 1707108
# Processing city: 1707207
# Processing city: 1707306
# Processing city: 1707405
# Processing city: 1707553
# Processing city: 1707652
# Processing city: 1707702
# Processing city: 1708205
# Processing city: 1708254
# Processing city: 1708304
# Processing city: 1709005
# Processing city: 1709302
# Processing city: 1709500
# Processing city: 1709807
# Processing city: 1710508
# Processing city: 1710706
# Processing city: 1710904
# Processing city: 1711100
# Processing city: 1711506
# Processing city: 1711803
# Processing city: 1711902
# Processing city: 1711951
# Processing city: 1712009
# Processing city: 1712157
# Processing city: 1712405
# Processing city: 1712454
# Processing city: 1712504
# Processing city: 1712702
# Processing city: 1712801
# Processing city: 1713205
# Processing city: 1713304
# Processing city: 1713601
# Processing city: 1713700
# Processing city: 1713809
# Processing city: 1713957
# Processing city: 1714203
# Processing city: 1714302
# Processing city: 1714880
# Processing city: 1715002
# Processing city: 1715101
# Processing city: 1715150
# Processing city: 1715259
# Processing city: 1715507
# Processing city: 1715705
# Processing city: 1715754
# Processing city: 1716109
# Processing city: 1716208
# Processing city: 1716307
# Processing city: 1716505
# Processing city: 1716604
# Processing city: 1716653
# Processing city: 1716703
# Processing city: 1717008
# Processing city: 1717206
# Processing city: 1717503
# Processing city: 1717800
# Processing city: 1717909
# Processing city: 1718006
# Processing city: 1718204
# Processing city: 1718303
# Processing city: 1718402
# Processing city: 1718451
# Processing city: 1718501
# Processing city: 1718550
# Processing city: 1718659
# Processing city: 1718709
# Processing city: 1718758
# Processing city: 1718808
# Processing city: 1718840
# Processing city: 1718865
# Processing city: 1718881
# Processing city: 1718899
# Processing city: 1718907
# Processing city: 1719004
# Processing city: 1720002
# Processing city: 1720101
# Processing city: 1720150
# Processing city: 1720200
# Processing city: 1720259
# Processing city: 1720309
# Processing city: 1720499
# Processing city: 1720655
# Processing city: 1720804
# Processing city: 1720853
# Processing city: 1720903
# Processing city: 1720937
# Processing city: 1720978
# Processing city: 1721000
# Processing city: 1721109
# Processing city: 1721208
# Processing city: 1721257
# Processing city: 1721307
# Processing city: 1722081
# Processing city: 1722107
# Processing city: 2100055
# Processing city: 2100105
# Processing city: 2100154
# Processing city: 2100204
# Processing city: 2100303
# Processing city: 2100402
# Processing city: 2100436
# Processing city: 2100477
# Processing city: 2100501
# Processing city: 2100550
# Processing city: 2100600
# Processing city: 2100709
# Processing city: 2100808
# Processing city: 2100832
# Processing city: 2100873
# Processing city: 2100907
# Processing city: 2100956
# Processing city: 2101004
# Processing city: 2101103
# Processing city: 2101202
# Processing city: 2101251
# Processing city: 2101301
# Processing city: 2101350
# Processing city: 2101400
# Processing city: 2101509
# Processing city: 2101608
# Processing city: 2101707
# Processing city: 2101731
# Processing city: 2101772
# Processing city: 2101806
# Processing city: 2101905
# Processing city: 2101939
# Processing city: 2101970
# Processing city: 2102002
# Processing city: 2102036
# Processing city: 2102077
# Processing city: 2102101
# Processing city: 2102150
# Processing city: 2102200
# Processing city: 2102309
# Processing city: 2102325
# Processing city: 2102358
# Processing city: 2102374
# Processing city: 2102408
# Processing city: 2102507
# Processing city: 2102556
# Processing city: 2102606
# Processing city: 2102705
# Processing city: 2102754
# Processing city: 2102804
# Processing city: 2102903
# Processing city: 2103000
# Processing city: 2103109
# Processing city: 2103125
# Processing city: 2103158
# Processing city: 2103174
# Processing city: 2103208
# Processing city: 2103257
# Processing city: 2103307
# Processing city: 2103406
# Processing city: 2103505
# Processing city: 2103554
# Processing city: 2103604
# Processing city: 2103703
# Processing city: 2103752
# Processing city: 2103802
# Processing city: 2103901
# Processing city: 2104008
# Processing city: 2104057
# Processing city: 2104073
# Processing city: 2104081
# Processing city: 2104099
# Processing city: 2104107
# Processing city: 2104206
# Processing city: 2104305
# Processing city: 2104404
# Processing city: 2104503
# Processing city: 2104552
# Processing city: 2104602
# Processing city: 2104628
# Processing city: 2104651
# Processing city: 2104677
# Processing city: 2104701
# Processing city: 2104800
# Processing city: 2104909
# Processing city: 2105005
# Processing city: 2105104
# Processing city: 2105153
# Processing city: 2105203
# Processing city: 2105302
# Processing city: 2105351
# Processing city: 2105401
# Processing city: 2105427
# Processing city: 2105450
# Processing city: 2105476
# Processing city: 2105500
# Processing city: 2105609
# Processing city: 2105658
# Processing city: 2105708
# Processing city: 2105807
# Processing city: 2105906
# Processing city: 2105922
# Processing city: 2105948
# Processing city: 2105963
# Processing city: 2105989
# Processing city: 2106003
# Processing city: 2106102
# Processing city: 2106201
# Processing city: 2106300
# Processing city: 2106326
# Processing city: 2106359
# Processing city: 2106375
# Processing city: 2106409
# Processing city: 2106508
# Processing city: 2106607
# Processing city: 2106631
# Processing city: 2106672
# Processing city: 2106706
# Processing city: 2106755
# Processing city: 2106805
# Processing city: 2106904
# Processing city: 2107001
# Processing city: 2107100
# Processing city: 2107209
# Processing city: 2107258
# Processing city: 2107308
# Processing city: 2107357
# Processing city: 2107407
# Processing city: 2107456
# Processing city: 2107506
# Processing city: 2107605
# Processing city: 2107704
# Processing city: 2107803
# Processing city: 2107902
# Processing city: 2108009
# Processing city: 2108058
# Processing city: 2108108
# Processing city: 2108207
# Processing city: 2108256
# Processing city: 2108306
# Processing city: 2108405
# Processing city: 2108454
# Processing city: 2108504
# Processing city: 2108603
# Processing city: 2108702
# Processing city: 2108801
# Processing city: 2108900
# Processing city: 2109007
# Processing city: 2109056
# Processing city: 2109106
# Processing city: 2109205
# Processing city: 2109239
# Processing city: 2109270
# Processing city: 2109304
# Processing city: 2109403
# Processing city: 2109452
# Processing city: 2109502
# Processing city: 2109551
# Processing city: 2109601
# Processing city: 2109700
# Processing city: 2109759
# Processing city: 2109809
# Processing city: 2109908
# Processing city: 2110005
# Processing city: 2110039
# Processing city: 2110104
# Processing city: 2110203
# Processing city: 2110237
# Processing city: 2110278
# Processing city: 2110302
# Processing city: 2110401
# Processing city: 2110500
# Processing city: 2110609
# Processing city: 2110658
# Processing city: 2110708
# Processing city: 2110807
# Processing city: 2110856
# Processing city: 2110906
# Processing city: 2111003
# Processing city: 2111029
# Processing city: 2111052
# Processing city: 2111078
# Processing city: 2111102
# Processing city: 2111201
# Processing city: 2111250
# Processing city: 2111300
# Processing city: 2111409
# Processing city: 2111508
# Processing city: 2111532
# Processing city: 2111573
# Processing city: 2111607
# Processing city: 2111631
# Processing city: 2111672
# Processing city: 2111706
# Processing city: 2111722
# Processing city: 2111748
# Processing city: 2111763
# Processing city: 2111789
# Processing city: 2111805
# Processing city: 2111904
# Processing city: 2111953
# Processing city: 2112001
# Processing city: 2112100
# Processing city: 2112209
# Processing city: 2112233
# Processing city: 2112274
# Processing city: 2112308
# Processing city: 2112407
# Processing city: 2112456
# Processing city: 2112506
# Processing city: 2112605
# Processing city: 2112704
# Processing city: 2112803
# Processing city: 2112852
# Processing city: 2112902
# Processing city: 2113009
# Processing city: 2114007
# Processing city: 2200053
# Processing city: 2200103
# Processing city: 2200202
# Processing city: 2200251
# Processing city: 2200277
# Processing city: 2200301
# Processing city: 2200400
# Processing city: 2200459
# Processing city: 2200509
# Processing city: 2200608
# Processing city: 2200707
# Processing city: 2200806
# Processing city: 2200905
# Processing city: 2200954
# Processing city: 2201002
# Processing city: 2201051
# Processing city: 2201101
# Processing city: 2201150
# Processing city: 2201176
# Processing city: 2201200
# Processing city: 2201309
# Processing city: 2201408
# Processing city: 2201507
# Processing city: 2201556
# Processing city: 2201572
# Processing city: 2201606
# Processing city: 2201705
# Processing city: 2201739
# Processing city: 2201770
# Processing city: 2201804
# Processing city: 2201903
# Processing city: 2201919
# Processing city: 2201929
# Processing city: 2201945
# Processing city: 2201960
# Processing city: 2201988
# Processing city: 2202000
# Processing city: 2202026
# Processing city: 2202059
# Processing city: 2202075
# Processing city: 2202083
# Processing city: 2202091
# Processing city: 2202109
# Processing city: 2202117
# Processing city: 2202133
# Processing city: 2202174
# Processing city: 2202208
# Processing city: 2202251
# Processing city: 2202307
# Processing city: 2202406
# Processing city: 2202455
# Processing city: 2202505
# Processing city: 2202539
# Processing city: 2202554
# Processing city: 2202604
# Processing city: 2202653
# Processing city: 2202703
# Processing city: 2202711
# Processing city: 2202729
# Processing city: 2202737
# Processing city: 2202752
# Processing city: 2202778
# Processing city: 2202802
# Processing city: 2202851
# Processing city: 2202901
# Processing city: 2203008
# Processing city: 2203107
# Processing city: 2203206
# Processing city: 2203230
# Processing city: 2203255
# Processing city: 2203271
# Processing city: 2203305
# Processing city: 2203354
# Processing city: 2203404
# Processing city: 2203420
# Processing city: 2203453
# Processing city: 2203503
# Processing city: 2203602
# Processing city: 2203701
# Processing city: 2203750
# Processing city: 2203800
# Processing city: 2203859
# Processing city: 2203909
# Processing city: 2204006
# Processing city: 2204105
# Processing city: 2204154
# Processing city: 2204204
# Processing city: 2204303
# Processing city: 2204352
# Processing city: 2204402
# Processing city: 2204501
# Processing city: 2204550
# Processing city: 2204600
# Processing city: 2204659
# Processing city: 2204709
# Processing city: 2204808
# Processing city: 2204907
# Processing city: 2205003
# Processing city: 2205102
# Processing city: 2205151
# Processing city: 2205201
# Processing city: 2205250
# Processing city: 2205276
# Processing city: 2205300
# Processing city: 2205359
# Processing city: 2205409
# Processing city: 2205458
# Processing city: 2205508
# Processing city: 2205516
# Processing city: 2205524
# Processing city: 2205532
# Processing city: 2205540
# Processing city: 2205557
# Processing city: 2205565
# Processing city: 2205573
# Processing city: 2205581
# Processing city: 2205599
# Processing city: 2205607
# Processing city: 2205706
# Processing city: 2205805
# Processing city: 2205854
# Processing city: 2205904
# Processing city: 2205953
# Processing city: 2206001
# Processing city: 2206050
# Processing city: 2206100
# Processing city: 2206209
# Processing city: 2206308
# Processing city: 2206357
# Processing city: 2206407
# Processing city: 2206506
# Processing city: 2206605
# Processing city: 2206654
# Processing city: 2206670
# Processing city: 2206696
# Processing city: 2206704
# Processing city: 2206720
# Processing city: 2206753
# Processing city: 2206803
# Processing city: 2206902
# Processing city: 2206951
# Processing city: 2207009
# Processing city: 2207108
# Processing city: 2207207
# Processing city: 2207306
# Processing city: 2207355
# Processing city: 2207405
# Processing city: 2207504
# Processing city: 2207553
# Processing city: 2207603
# Processing city: 2207702
# Processing city: 2207751
# Processing city: 2207777
# Processing city: 2207793
# Processing city: 2207801
# Processing city: 2207850
# Processing city: 2207900
# Processing city: 2207934
# Processing city: 2207959
# Processing city: 2208007
# Processing city: 2208106
# Processing city: 2208205
# Processing city: 2208304
# Processing city: 2208403
# Processing city: 2208502
# Processing city: 2208551
# Processing city: 2208601
# Processing city: 2208650
# Processing city: 2208700
# Processing city: 2208809
# Processing city: 2208858
# Processing city: 2208874
# Processing city: 2208908
# Processing city: 2209005
# Processing city: 2209104
# Processing city: 2209153
# Processing city: 2209203
# Processing city: 2209302
# Processing city: 2209351
# Processing city: 2209377
# Processing city: 2209401
# Processing city: 2209450
# Processing city: 2209500
# Processing city: 2209559
# Processing city: 2209609
# Processing city: 2209658
# Processing city: 2209708
# Processing city: 2209757
# Processing city: 2209807
# Processing city: 2209856
# Processing city: 2209872
# Processing city: 2209906
# Processing city: 2209955
# Processing city: 2209971
# Processing city: 2210003
# Processing city: 2210052
# Processing city: 2210102
# Processing city: 2210201
# Processing city: 2210300
# Processing city: 2210359
# Processing city: 2210375
# Processing city: 2210383
# Processing city: 2210391
# Processing city: 2210409
# Processing city: 2210508
# Processing city: 2210607
# Processing city: 2210623
# Processing city: 2210631
# Processing city: 2210656
# Processing city: 2210706
# Processing city: 2210805
# Processing city: 2210904
# Processing city: 2210938
# Processing city: 2210953
# Processing city: 2210979
# Processing city: 2211001
# Processing city: 2211100
# Processing city: 2211209
# Processing city: 2211308
# Processing city: 2211357
# Processing city: 2211407
# Processing city: 2211506
# Processing city: 2211605
# Processing city: 2211704
# Processing city: 2300101
# Processing city: 2300150
# Processing city: 2300200
# Processing city: 2300309
# Processing city: 2300408
# Processing city: 2300507
# Processing city: 2300606
# Processing city: 2300705
# Processing city: 2300754
# Processing city: 2300804
# Processing city: 2300903
# Processing city: 2301000
# Processing city: 2301109
# Processing city: 2301208
# Processing city: 2301257
# Processing city: 2301307
# Processing city: 2301406
# Processing city: 2301505
# Processing city: 2301604
# Processing city: 2301703
# Processing city: 2301802
# Processing city: 2301851
# Processing city: 2301901
# Processing city: 2301950
# Processing city: 2302008
# Processing city: 2302057
# Processing city: 2302107
# Processing city: 2302206
# Processing city: 2302305
# Processing city: 2302404
# Processing city: 2302503
# Processing city: 2302602
# Processing city: 2302701
# Processing city: 2302800
# Processing city: 2302909
# Processing city: 2303006
# Processing city: 2303105
# Processing city: 2303204
# Processing city: 2303303
# Processing city: 2303402
# Processing city: 2303501
# Processing city: 2303600
# Processing city: 2303659
# Processing city: 2303709
# Processing city: 2303808
# Processing city: 2303907
# Processing city: 2303931
# Processing city: 2303956
# Processing city: 2304004
# Processing city: 2304103
# Processing city: 2304202
# Processing city: 2304236
# Processing city: 2304251
# Processing city: 2304269
# Processing city: 2304277
# Processing city: 2304285
# Processing city: 2304301
# Processing city: 2304350
# Processing city: 2304400
# Processing city: 2304459
# Processing city: 2304509
# Processing city: 2304608
# Processing city: 2304657
# Processing city: 2304707
# Processing city: 2304806
# Processing city: 2304905
# Processing city: 2304954
# Processing city: 2305001
# Processing city: 2305100
# Processing city: 2305209
# Processing city: 2305233
# Processing city: 2305266
# Processing city: 2305308
# Processing city: 2305332
# Processing city: 2305357
# Processing city: 2305407
# Processing city: 2305506
# Processing city: 2305605
# Processing city: 2305654
# Processing city: 2305704
# Processing city: 2305803
# Processing city: 2305902
# Processing city: 2306009
# Processing city: 2306108
# Processing city: 2306207
# Processing city: 2306256
# Processing city: 2306306
# Processing city: 2306405
# Processing city: 2306504
# Processing city: 2306553
# Processing city: 2306603
# Processing city: 2306702
# Processing city: 2306801
# Processing city: 2306900
# Processing city: 2307007
# Processing city: 2307106
# Processing city: 2307205
# Processing city: 2307254
# Processing city: 2307304
# Processing city: 2307403
# Processing city: 2307502
# Processing city: 2307601
# Processing city: 2307635
# Processing city: 2307650
# Processing city: 2307700
# Processing city: 2307809
# Processing city: 2307908
# Processing city: 2308005
# Processing city: 2308104
# Processing city: 2308203
# Processing city: 2308302
# Processing city: 2308351
# Processing city: 2308377
# Processing city: 2308401
# Processing city: 2308500
# Processing city: 2308609
# Processing city: 2308708
# Processing city: 2308807
# Processing city: 2308906
# Processing city: 2309003
# Processing city: 2309102
# Processing city: 2309201
# Processing city: 2309300
# Processing city: 2309409
# Processing city: 2309458
# Processing city: 2309508
# Processing city: 2309607
# Processing city: 2309706
# Processing city: 2309805
# Processing city: 2309904
# Processing city: 2310001
# Processing city: 2310100
# Processing city: 2310209
# Processing city: 2310258
# Processing city: 2310308
# Processing city: 2310407
# Processing city: 2310506
# Processing city: 2310605
# Processing city: 2310704
# Processing city: 2310803
# Processing city: 2310852
# Processing city: 2310902
# Processing city: 2310951
# Processing city: 2311009
# Processing city: 2311108
# Processing city: 2311207
# Processing city: 2311231
# Processing city: 2311264
# Processing city: 2311306
# Processing city: 2311355
# Processing city: 2311405
# Processing city: 2311504
# Processing city: 2311603
# Processing city: 2311702
# Processing city: 2311801
# Processing city: 2311900
# Processing city: 2311959
# Processing city: 2312007
# Processing city: 2312106
# Processing city: 2312205
# Processing city: 2312304
# Processing city: 2312403
# Processing city: 2312502
# Processing city: 2312601
# Processing city: 2312700
# Processing city: 2312809
# Processing city: 2312908
# Processing city: 2313005
# Processing city: 2313104
# Processing city: 2313203
# Processing city: 2313252
# Processing city: 2313302
# Processing city: 2313351
# Processing city: 2313401
# Processing city: 2313500
# Processing city: 2313559
# Processing city: 2313609
# Processing city: 2313708
# Processing city: 2313757
# Processing city: 2313807
# Processing city: 2313906
# Processing city: 2313955
# Processing city: 2314003
# Processing city: 2314102
# Processing city: 2400109
# Processing city: 2400208
# Processing city: 2400307
# Processing city: 2400406
# Processing city: 2400505
# Processing city: 2400604
# Processing city: 2400703
# Processing city: 2400802
# Processing city: 2400901
# Processing city: 2401008
# Processing city: 2401107
# Processing city: 2401206
# Processing city: 2401305
# Processing city: 2401404
# Processing city: 2401453
# Processing city: 2401503
# Processing city: 2401602
# Processing city: 2401651
# Processing city: 2401701
# Processing city: 2401800
# Processing city: 2401859
# Processing city: 2401909
# Processing city: 2402006
# Processing city: 2402105
# Processing city: 2402204
# Processing city: 2402303
# Processing city: 2402402
# Processing city: 2402501
# Processing city: 2402600
# Processing city: 2402709
# Processing city: 2402808
# Processing city: 2402907
# Processing city: 2403004
# Processing city: 2403103
# Processing city: 2403202
# Processing city: 2403251
# Processing city: 2403301
# Processing city: 2403400
# Processing city: 2403509
# Processing city: 2403608
# Processing city: 2403707
# Processing city: 2403756
# Processing city: 2403806
# Processing city: 2403905
# Processing city: 2404002
# Processing city: 2404101
# Processing city: 2404200
# Processing city: 2404309
# Processing city: 2404408
# Processing city: 2404507
# Processing city: 2404606
# Processing city: 2404705
# Processing city: 2404804
# Processing city: 2404853
# Processing city: 2404903
# Processing city: 2405009
# Processing city: 2405108
# Processing city: 2405207
# Processing city: 2405306
# Processing city: 2405405
# Processing city: 2405504
# Processing city: 2405603
# Processing city: 2405702
# Processing city: 2405801
# Processing city: 2405900
# Processing city: 2406007
# Processing city: 2406106
# Processing city: 2406155
# Processing city: 2406205
# Processing city: 2406304
# Processing city: 2406403
# Processing city: 2406502
# Processing city: 2406601
# Processing city: 2406700
# Processing city: 2406809
# Processing city: 2406908
# Processing city: 2407005
# Processing city: 2407104
# Processing city: 2407203
# Processing city: 2407252
# Processing city: 2407302
# Processing city: 2407401
# Processing city: 2407500
# Processing city: 2407609
# Processing city: 2407708
# Processing city: 2407807
# Processing city: 2407906
# Processing city: 2408003
# Processing city: 2408102
# Processing city: 2408201
# Processing city: 2408300
# Processing city: 2408409
# Processing city: 2408508
# Processing city: 2408607
# Processing city: 2408706
# Processing city: 2408805
# Processing city: 2408904
# Processing city: 2408953
# Processing city: 2409100
# Processing city: 2409209
# Processing city: 2409308
# Processing city: 2409332
# Processing city: 2409407
# Processing city: 2409506
# Processing city: 2409605
# Processing city: 2409704
# Processing city: 2409803
# Processing city: 2409902
# Processing city: 2410009
# Processing city: 2410108
# Processing city: 2410207
# Processing city: 2410256
# Processing city: 2410306
# Processing city: 2410405
# Processing city: 2410504
# Processing city: 2410603
# Processing city: 2410702
# Processing city: 2410801
# Processing city: 2410900
# Processing city: 2411007
# Processing city: 2411056
# Processing city: 2411106
# Processing city: 2411205
# Processing city: 2411403
# Processing city: 2411429
# Processing city: 2411502
# Processing city: 2411601
# Processing city: 2411700
# Processing city: 2411809
# Processing city: 2411908
# Processing city: 2412005
# Processing city: 2412104
# Processing city: 2412203
# Processing city: 2412302
# Processing city: 2412401
# Processing city: 2412500
# Processing city: 2412559
# Processing city: 2412609
# Processing city: 2412708
# Processing city: 2412807
# Processing city: 2412906
# Processing city: 2413003
# Processing city: 2413102
# Processing city: 2413201
# Processing city: 2413300
# Processing city: 2413359
# Processing city: 2413409
# Processing city: 2413508
# Processing city: 2413557
# Processing city: 2413607
# Processing city: 2413706
# Processing city: 2413805
# Processing city: 2413904
# Processing city: 2414001
# Processing city: 2414100
# Processing city: 2414159
# Processing city: 2414209
# Processing city: 2414308
# Processing city: 2414407
# Processing city: 2414456
# Processing city: 2414506
# Processing city: 2414605
# Processing city: 2414704
# Processing city: 2414753
# Processing city: 2414803
# Processing city: 2414902
# Processing city: 2415008
# Processing city: 2500106
# Processing city: 2500205
# Processing city: 2500304
# Processing city: 2500403
# Processing city: 2500502
# Processing city: 2500536
# Processing city: 2500577
# Processing city: 2500601
# Processing city: 2500700
# Processing city: 2500734
# Processing city: 2500775
# Processing city: 2500809
# Processing city: 2500908
# Processing city: 2501005
# Processing city: 2501104
# Processing city: 2501153
# Processing city: 2501203
# Processing city: 2501302
# Processing city: 2501351
# Processing city: 2501401
# Processing city: 2501500
# Processing city: 2501534
# Processing city: 2501575
# Processing city: 2501609
# Processing city: 2501708
# Processing city: 2501807
# Processing city: 2501906
# Processing city: 2502003
# Processing city: 2502052
# Processing city: 2502102
# Processing city: 2502151
# Processing city: 2502201
# Processing city: 2502300
# Processing city: 2502409
# Processing city: 2502508
# Processing city: 2502607
# Processing city: 2502706
# Processing city: 2502805
# Processing city: 2502904
# Processing city: 2503001
# Processing city: 2503100
# Processing city: 2503209
# Processing city: 2503308
# Processing city: 2503407
# Processing city: 2503506
# Processing city: 2503555
# Processing city: 2503605
# Processing city: 2503704
# Processing city: 2503753
# Processing city: 2503803
# Processing city: 2503902
# Processing city: 2504009
# Processing city: 2504033
# Processing city: 2504074
# Processing city: 2504108
# Processing city: 2504157
# Processing city: 2504207
# Processing city: 2504306
# Processing city: 2504355
# Processing city: 2504405
# Processing city: 2504504
# Processing city: 2504603
# Processing city: 2504702
# Processing city: 2504801
# Processing city: 2504850
# Processing city: 2504900
# Processing city: 2505006
# Processing city: 2505105
# Processing city: 2505204
# Processing city: 2505238
# Processing city: 2505279
# Processing city: 2505303
# Processing city: 2505352
# Processing city: 2505402
# Processing city: 2505501
# Processing city: 2505600
# Processing city: 2505709
# Processing city: 2505808
# Processing city: 2505907
# Processing city: 2506004
# Processing city: 2506103
# Processing city: 2506202
# Processing city: 2506251
# Processing city: 2506301
# Processing city: 2506400
# Processing city: 2506509
# Processing city: 2506608
# Processing city: 2506707
# Processing city: 2506806
# Processing city: 2506905
# Processing city: 2507002
# Processing city: 2507101
# Processing city: 2507200
# Processing city: 2507309
# Processing city: 2507408
# Processing city: 2507507
# Processing city: 2507606
# Processing city: 2507705
# Processing city: 2507804
# Processing city: 2507903
# Processing city: 2508000
# Processing city: 2508109
# Processing city: 2508208
# Processing city: 2508307
# Processing city: 2508406
# Processing city: 2508505
# Processing city: 2508554
# Processing city: 2508604
# Processing city: 2508703
# Processing city: 2508802
# Processing city: 2508901
# Processing city: 2509008
# Processing city: 2509057
# Processing city: 2509107
# Processing city: 2509156
# Processing city: 2509206
# Processing city: 2509305
# Processing city: 2509339
# Processing city: 2509370
# Processing city: 2509396
# Processing city: 2509404
# Processing city: 2509503
# Processing city: 2509602
# Processing city: 2509701
# Processing city: 2509800
# Processing city: 2509909
# Processing city: 2510006
# Processing city: 2510105
# Processing city: 2510204
# Processing city: 2510303
# Processing city: 2510402
# Processing city: 2510501
# Processing city: 2510600
# Processing city: 2510659
# Processing city: 2510709
# Processing city: 2510808
# Processing city: 2510907
# Processing city: 2511004
# Processing city: 2511103
# Processing city: 2511202
# Processing city: 2511301
# Processing city: 2511400
# Processing city: 2511509
# Processing city: 2511608
# Processing city: 2511707
# Processing city: 2511806
# Processing city: 2511905
# Processing city: 2512002
# Processing city: 2512036
# Processing city: 2512077
# Processing city: 2512101
# Processing city: 2512200
# Processing city: 2512309
# Processing city: 2512408
# Processing city: 2512507
# Processing city: 2512606
# Processing city: 2512705
# Processing city: 2512721
# Processing city: 2512747
# Processing city: 2512754
# Processing city: 2512762
# Processing city: 2512788
# Processing city: 2512804
# Processing city: 2512903
# Processing city: 2513000
# Processing city: 2513109
# Processing city: 2513158
# Processing city: 2513208
# Processing city: 2513307
# Processing city: 2513356
# Processing city: 2513406
# Processing city: 2513505
# Processing city: 2513604
# Processing city: 2513653
# Processing city: 2513703
# Processing city: 2513802
# Processing city: 2513851
# Processing city: 2513901
# Processing city: 2513927
# Processing city: 2513943
# Processing city: 2513968
# Processing city: 2513984
# Processing city: 2514008
# Processing city: 2514107
# Processing city: 2514206
# Processing city: 2514305
# Processing city: 2514404
# Processing city: 2514453
# Processing city: 2514503
# Processing city: 2514552
# Processing city: 2514602
# Processing city: 2514651
# Processing city: 2514701
# Processing city: 2514800
# Processing city: 2514909
# Processing city: 2515005
# Processing city: 2515104
# Processing city: 2515203
# Processing city: 2515302
# Processing city: 2515401
# Processing city: 2515500
# Processing city: 2515609
# Processing city: 2515708
# Processing city: 2515807
# Processing city: 2515906
# Processing city: 2515930
# Processing city: 2515971
# Processing city: 2516003
# Processing city: 2516102
# Processing city: 2516151
# Processing city: 2516201
# Processing city: 2516300
# Processing city: 2516409
# Processing city: 2516508
# Processing city: 2516607
# Processing city: 2516706
# Processing city: 2516755
# Processing city: 2516805
# Processing city: 2516904
# Processing city: 2517001
# Processing city: 2517100
# Processing city: 2517209
# Processing city: 2517407
# Processing city: 2600054
# Processing city: 2600104
# Processing city: 2600203
# Processing city: 2600302
# Processing city: 2600401
# Processing city: 2600500
# Processing city: 2600609
# Processing city: 2600708
# Processing city: 2600807
# Processing city: 2600906
# Processing city: 2601003
# Processing city: 2601052
# Processing city: 2601102
# Processing city: 2601201
# Processing city: 2601300
# Processing city: 2601409
# Processing city: 2601508
# Processing city: 2601607
# Processing city: 2601706
# Processing city: 2601805
# Processing city: 2601904
# Processing city: 2602001
# Processing city: 2602100
# Processing city: 2602209
# Processing city: 2602308
# Processing city: 2602407
# Processing city: 2602506
# Processing city: 2602605
# Processing city: 2602704
# Processing city: 2602803
# Processing city: 2602902
# Processing city: 2603009
# Processing city: 2603108
# Processing city: 2603207
# Processing city: 2603306
# Processing city: 2603405
# Processing city: 2603454
# Processing city: 2603504
# Processing city: 2603603
# Processing city: 2603702
# Processing city: 2603801
# Processing city: 2603900
# Processing city: 2603926
# Processing city: 2604007
# Processing city: 2604106
# Processing city: 2604155
# Processing city: 2604205
# Processing city: 2604304
# Processing city: 2604403
# Processing city: 2604502
# Processing city: 2604601
# Processing city: 2604700
# Processing city: 2604809
# Processing city: 2604908
# Processing city: 2605004
# Processing city: 2605103
# Processing city: 2605152
# Processing city: 2605202
# Processing city: 2605301
# Processing city: 2605400
# Processing city: 2605459
# Processing city: 2605509
# Processing city: 2605608
# Processing city: 2605707
# Processing city: 2605806
# Processing city: 2605905
# Processing city: 2606002
# Processing city: 2606101
# Processing city: 2606200
# Processing city: 2606309
# Processing city: 2606408
# Processing city: 2606507
# Processing city: 2606606
# Processing city: 2606705
# Processing city: 2606804
# Processing city: 2606903
# Processing city: 2607000
# Processing city: 2607109
# Processing city: 2607208
# Processing city: 2607307
# Processing city: 2607406
# Processing city: 2607505
# Processing city: 2607604
# Processing city: 2607653
# Processing city: 2607703
# Processing city: 2607752
# Processing city: 2607802
# Processing city: 2607901
# Processing city: 2607950
# Processing city: 2608008
# Processing city: 2608057
# Processing city: 2608107
# Processing city: 2608206
# Processing city: 2608255
# Processing city: 2608305
# Processing city: 2608404
# Processing city: 2608453
# Processing city: 2608503
# Processing city: 2608602
# Processing city: 2608701
# Processing city: 2608750
# Processing city: 2608800
# Processing city: 2608909
# Processing city: 2609006
# Processing city: 2609105
# Processing city: 2609154
# Processing city: 2609204
# Processing city: 2609303
# Processing city: 2609402
# Processing city: 2609501
# Processing city: 2609600
# Processing city: 2609709
# Processing city: 2609808
# Processing city: 2609907
# Processing city: 2610004
# Processing city: 2610103
# Processing city: 2610202
# Processing city: 2610301
# Processing city: 2610400
# Processing city: 2610509
# Processing city: 2610608
# Processing city: 2610707
# Processing city: 2610806
# Processing city: 2610905
# Processing city: 2611002
# Processing city: 2611101
# Processing city: 2611200
# Processing city: 2611309
# Processing city: 2611408
# Processing city: 2611507
# Processing city: 2611533
# Processing city: 2611606
# Processing city: 2611705
# Processing city: 2611804
# Processing city: 2611903
# Processing city: 2612000
# Processing city: 2612109
# Processing city: 2612208
# Processing city: 2612307
# Processing city: 2612406
# Processing city: 2612455
# Processing city: 2612471
# Processing city: 2612505
# Processing city: 2612554
# Processing city: 2612604
# Processing city: 2612703
# Processing city: 2612802
# Processing city: 2612901
# Processing city: 2613008
# Processing city: 2613107
# Processing city: 2613206
# Processing city: 2613305
# Processing city: 2613404
# Processing city: 2613503
# Processing city: 2613602
# Processing city: 2613701
# Processing city: 2613800
# Processing city: 2613909
# Processing city: 2614006
# Processing city: 2614105
# Processing city: 2614204
# Processing city: 2614303
# Processing city: 2614402
# Processing city: 2614501
# Processing city: 2614600
# Processing city: 2614709
# Processing city: 2614808
# Processing city: 2614857
# Processing city: 2615003
# Processing city: 2615102
# Processing city: 2615201
# Processing city: 2615300
# Processing city: 2615409
# Processing city: 2615508
# Processing city: 2615607
# Processing city: 2615706
# Processing city: 2615805
# Processing city: 2615904
# Processing city: 2616001
# Processing city: 2616100
# Processing city: 2616183
# Processing city: 2616209
# Processing city: 2616308
# Processing city: 2616407
# Processing city: 2616506
# Processing city: 2700102
# Processing city: 2700201
# Processing city: 2700300
# Processing city: 2700409
# Processing city: 2700508
# Processing city: 2700607
# Processing city: 2700706
# Processing city: 2700805
# Processing city: 2700904
# Processing city: 2701001
# Processing city: 2701100
# Processing city: 2701209
# Processing city: 2701308
# Processing city: 2701357
# Processing city: 2701407
# Processing city: 2701506
# Processing city: 2701605
# Processing city: 2701704
# Processing city: 2701803
# Processing city: 2701902
# Processing city: 2702009
# Processing city: 2702108
# Processing city: 2702207
# Processing city: 2702306
# Processing city: 2702355
# Processing city: 2702405
# Processing city: 2702504
# Processing city: 2702553
# Processing city: 2702603
# Processing city: 2702702
# Processing city: 2702801
# Processing city: 2702900
# Processing city: 2703007
# Processing city: 2703106
# Processing city: 2703205
# Processing city: 2703304
# Processing city: 2703403
# Processing city: 2703502
# Processing city: 2703601
# Processing city: 2703700
# Processing city: 2703759
# Processing city: 2703809
# Processing city: 2703908
# Processing city: 2704005
# Processing city: 2704104
# Processing city: 2704203
# Processing city: 2704302
# Processing city: 2704401
# Processing city: 2704500
# Processing city: 2704609
# Processing city: 2704708
# Processing city: 2704807
# Processing city: 2704906
# Processing city: 2705002
# Processing city: 2705101
# Processing city: 2705200
# Processing city: 2705309
# Processing city: 2705408
# Processing city: 2705507
# Processing city: 2705606
# Processing city: 2705705
# Processing city: 2705804
# Processing city: 2705903
# Processing city: 2706000
# Processing city: 2706109
# Processing city: 2706208
# Processing city: 2706307
# Processing city: 2706406
# Processing city: 2706422
# Processing city: 2706448
# Processing city: 2706505
# Processing city: 2706604
# Processing city: 2706703
# Processing city: 2706802
# Processing city: 2706901
# Processing city: 2707008
# Processing city: 2707107
# Processing city: 2707206
# Processing city: 2707305
# Processing city: 2707404
# Processing city: 2707503
# Processing city: 2707602
# Processing city: 2707701
# Processing city: 2707800
# Processing city: 2707909
# Processing city: 2708006
# Processing city: 2708105
# Processing city: 2708204
# Processing city: 2708303
# Processing city: 2708402
# Processing city: 2708501
# Processing city: 2708600
# Processing city: 2708709
# Processing city: 2708808
# Processing city: 2708907
# Processing city: 2708956
# Processing city: 2709004
# Processing city: 2709103
# Processing city: 2709152
# Processing city: 2709202
# Processing city: 2709301
# Processing city: 2709400
# Processing city: 2800100
# Processing city: 2800209
# Processing city: 2800308
# Processing city: 2800407
# Processing city: 2800506
# Processing city: 2800605
# Processing city: 2800670
# Processing city: 2800704
# Processing city: 2801009
# Processing city: 2801108
# Processing city: 2801207
# Processing city: 2801306
# Processing city: 2801405
# Processing city: 2801504
# Processing city: 2801603
# Processing city: 2801702
# Processing city: 2801900
# Processing city: 2802007
# Processing city: 2802106
# Processing city: 2802205
# Processing city: 2802304
# Processing city: 2802403
# Processing city: 2802502
# Processing city: 2802601
# Processing city: 2802700
# Processing city: 2802809
# Processing city: 2802908
# Processing city: 2803005
# Processing city: 2803104
# Processing city: 2803203
# Processing city: 2803302
# Processing city: 2803401
# Processing city: 2803500
# Processing city: 2803609
# Processing city: 2803708
# Processing city: 2803807
# Processing city: 2803906
# Processing city: 2804003
# Processing city: 2804102
# Processing city: 2804201
# Processing city: 2804300
# Processing city: 2804409
# Processing city: 2804458
# Processing city: 2804508
# Processing city: 2804607
# Processing city: 2804706
# Processing city: 2804805
# Processing city: 2804904
# Processing city: 2805000
# Processing city: 2805109
# Processing city: 2805208
# Processing city: 2805307
# Processing city: 2805406
# Processing city: 2805505
# Processing city: 2805604
# Processing city: 2805703
# Processing city: 2805802
# Processing city: 2805901
# Processing city: 2806008
# Processing city: 2806107
# Processing city: 2806206
# Processing city: 2806305
# Processing city: 2806404
# Processing city: 2806503
# Processing city: 2806602
# Processing city: 2806701
# Processing city: 2806800
# Processing city: 2806909
# Processing city: 2807006
# Processing city: 2807105
# Processing city: 2807204
# Processing city: 2807303
# Processing city: 2807402
# Processing city: 2807501
# Processing city: 2807600
# Processing city: 2900108
# Processing city: 2900207
# Processing city: 2900306
# Processing city: 2900355
# Processing city: 2900405
# Processing city: 2900504
# Processing city: 2900603
# Processing city: 2900702
# Processing city: 2900801
# Processing city: 2900900
# Processing city: 2901007
# Processing city: 2901106
# Processing city: 2901155
# Processing city: 2901205
# Processing city: 2901304
# Processing city: 2901353
# Processing city: 2901403
# Processing city: 2901502
# Processing city: 2901601
# Processing city: 2901700
# Processing city: 2901809
# Processing city: 2901908
# Processing city: 2901957
# Processing city: 2902005
# Processing city: 2902054
# Processing city: 2902104
# Processing city: 2902203
# Processing city: 2902252
# Processing city: 2902302
# Processing city: 2902401
# Processing city: 2902500
# Processing city: 2902609
# Processing city: 2902658
# Processing city: 2902708
# Processing city: 2902807
# Processing city: 2902906
# Processing city: 2903003
# Processing city: 2903102
# Processing city: 2903201
# Processing city: 2903235
# Processing city: 2903276
# Processing city: 2903300
# Processing city: 2903409
# Processing city: 2903508
# Processing city: 2903607
# Processing city: 2903706
# Processing city: 2903805
# Processing city: 2903904
# Processing city: 2903953
# Processing city: 2904001
# Processing city: 2904050
# Processing city: 2904100
# Processing city: 2904209
# Processing city: 2904308
# Processing city: 2904407
# Processing city: 2904506
# Processing city: 2904605
# Processing city: 2904704
# Processing city: 2904753
# Processing city: 2904803
# Processing city: 2904852
# Processing city: 2904902
# Processing city: 2905008
# Processing city: 2905107
# Processing city: 2905156
# Processing city: 2905206
# Processing city: 2905305
# Processing city: 2905404
# Processing city: 2905503
# Processing city: 2905602
# Processing city: 2905701
# Processing city: 2905800
# Processing city: 2905909
# Processing city: 2906006
# Processing city: 2906105
# Processing city: 2906204
# Processing city: 2906303
# Processing city: 2906402
# Processing city: 2906501
# Processing city: 2906600
# Processing city: 2906709
# Processing city: 2906808
# Processing city: 2906824
# Processing city: 2906857
# Processing city: 2906873
# Processing city: 2906899
# Processing city: 2906907
# Processing city: 2907004
# Processing city: 2907103
# Processing city: 2907202
# Processing city: 2907301
# ...
# Processing city: 4314803
# Processing city: 4314902
# Processing city: 4315008
# Processing city: 4315057
# Processing city: 4315073
# Processing city: 4315107
# Processing city: 4315131
# Processing city: 4315149
# Processing city: 4315156
# Processing city: 4315172
# Processing city: 4315206
# Processing city: 4315305
# Processing city: 4315313
# Processing city: 4315321
# Processing city: 4315354
# Processing city: 4315404
# Processing city: 4315453
# Processing city: 4315503
# Processing city: 4315552
# Processing city: 4315602
# Processing city: 4315701
# Processing city: 4315750
# Processing city: 4315800
# Processing city: 4315909
# Processing city: 4315958
# Processing city: 4316006
# Processing city: 4316105
# Processing city: 4316204
# Processing city: 4316303
# Processing city: 4316402
# Processing city: 4316428
# Processing city: 4316436
# Processing city: 4316451
# Processing city: 4316477
# Processing city: 4316501
# Processing city: 4316600
# Processing city: 4316709
# Processing city: 4316733
# Processing city: 4316758
# Processing city: 4316808
# Processing city: 4316907
# Processing city: 4316956
# Processing city: 4316972
# Processing city: 4317004
# Processing city: 4317103
# Processing city: 4317202
# Processing city: 4317251
# Processing city: 4317301
# Processing city: 4317400
# Processing city: 4317509
# Processing city: 4317558
# Processing city: 4317608
# Processing city: 4317707
# Processing city: 4317756
# Processing city: 4317806
# Processing city: 4317905
# Processing city: 4317954
# Processing city: 4318002
# Processing city: 4318051
# Processing city: 4318101
# Processing city: 4318200
# Processing city: 4318309
# Processing city: 4318408
# Processing city: 4318424
# Processing city: 4318432
# Processing city: 4318440
# Processing city: 4318457
# Processing city: 4318465
# Processing city: 4318481
# Processing city: 4318499
# Processing city: 4318507
# Processing city: 4318606
# Processing city: 4318614
# Processing city: 4318622
# Processing city: 4318705
# Processing city: 4318804
# Processing city: 4318903
# Processing city: 4319000
# Processing city: 4319109
# Processing city: 4319125
# Processing city: 4319158
# Processing city: 4319208
# Processing city: 4319307
# Processing city: 4319356
# Processing city: 4319364
# Processing city: 4319372
# Processing city: 4319406
# Processing city: 4319505
# Processing city: 4319604
# Processing city: 4319703
# Processing city: 4319711
# Processing city: 4319737
# Processing city: 4319752
# Processing city: 4319802
# Processing city: 4319901
# Processing city: 4320008
# Processing city: 4320107
# Processing city: 4320206
# Processing city: 4320230
# Processing city: 4320263
# Processing city: 4320305
# Processing city: 4320321
# Processing city: 4320354
# Processing city: 4320404
# Processing city: 4320453
# Processing city: 4320503
# Processing city: 4320552
# Processing city: 4320578
# Processing city: 4320602
# Processing city: 4320651
# Processing city: 4320677
# Processing city: 4320701
# Processing city: 4320800
# Processing city: 4320859
# Processing city: 4320909
# Processing city: 4321006
# Processing city: 4321105
# Processing city: 4321204
# Processing city: 4321303
# Processing city: 4321329
# Processing city: 4321352
# Processing city: 4321402
# Processing city: 4321436
# Processing city: 4321451
# Processing city: 4321469
# Processing city: 4321477
# Processing city: 4321493
# Processing city: 4321501
# Processing city: 4321600
# Processing city: 4321626
# Processing city: 4321634
# Processing city: 4321667
# Processing city: 4321709
# Processing city: 4321808
# Processing city: 4321832
# Processing city: 4321857
# Processing city: 4321907
# Processing city: 4321956
# Processing city: 4322004
# Processing city: 4322103
# Processing city: 4322152
# Processing city: 4322186
# Processing city: 4322202
# Processing city: 4322251
# Processing city: 4322301
# Processing city: 4322327
# Processing city: 4322343
# Processing city: 4322350
# Processing city: 4322376
# Processing city: 4322400
# Processing city: 4322509
# Processing city: 4322525
# Processing city: 4322533
# Processing city: 4322541
# Processing city: 4322558
# Processing city: 4322608
# Processing city: 4322707
# Processing city: 4322806
# Processing city: 4322855
# Processing city: 4322905
# Processing city: 4323002
# Processing city: 4323101
# Processing city: 4323200
# Processing city: 4323309
# Processing city: 4323358
# Processing city: 4323408
# Processing city: 4323457
# Processing city: 4323507
# Processing city: 4323606
# Processing city: 4323705
# Processing city: 4323754
# Processing city: 4323770
# Processing city: 4323804
# Processing city: 5000203
# Processing city: 5000252
# Processing city: 5000609
# Processing city: 5000708
# Processing city: 5000807
# Processing city: 5000856
# Processing city: 5000906
# Processing city: 5001003
# Processing city: 5001102
# Processing city: 5001243
# Processing city: 5001508
# Processing city: 5001904
# Processing city: 5002001
# Processing city: 5002100
# Processing city: 5002159
# Processing city: 5002209
# Processing city: 5002308
# Processing city: 5002407
# Processing city: 5002605
# Processing city: 5002704
# Processing city: 5002803
# Processing city: 5002902
# Processing city: 5002951
# Processing city: 5003108
# Processing city: 5003157
# Processing city: 5003207
# Processing city: 5003256
# Processing city: 5003306
# Processing city: 5003454
# Processing city: 5003488
# Processing city: 5003504
# Processing city: 5003702
# Processing city: 5003751
# Processing city: 5003801
# Processing city: 5003900
# Processing city: 5004007
# Processing city: 5004106
# Processing city: 5004304
# Processing city: 5004403
# Processing city: 5004502
# Processing city: 5004601
# Processing city: 5004700
# Processing city: 5004809
# Processing city: 5004908
# Processing city: 5005004
# Processing city: 5005103
# Processing city: 5005152
# Processing city: 5005202
# Processing city: 5005251
# Processing city: 5005400
# Processing city: 5005608
# Processing city: 5005681
# Processing city: 5005707
# Processing city: 5005806
# Processing city: 5006002
# Processing city: 5006200
# Processing city: 5006259
# Processing city: 5006275
# Processing city: 5006309
# Processing city: 5006358
# Processing city: 5006408
# Processing city: 5006606
# Processing city: 5006903
# Processing city: 5007109
# Processing city: 5007208
# Processing city: 5007307
# Processing city: 5007406
# Processing city: 5007505
# Processing city: 5007554
# Processing city: 5007695
# Processing city: 5007703
# Processing city: 5007802
# Processing city: 5007901
# Processing city: 5007935
# Processing city: 5007950
# Processing city: 5007976
# Processing city: 5008008
# Processing city: 5008305
# Processing city: 5008404
# Processing city: 5100102
# Processing city: 5100201
# Processing city: 5100250
# Processing city: 5100300
# Processing city: 5100359
# Processing city: 5100409
# Processing city: 5100508
# Processing city: 5100607
# Processing city: 5100805
# Processing city: 5101001
# Processing city: 5101209
# Processing city: 5101258
# Processing city: 5101308
# Processing city: 5101407
# Processing city: 5101605
# Processing city: 5101704
# Processing city: 5101803
# Processing city: 5101852
# Processing city: 5101902
# Processing city: 5102504
# Processing city: 5102603
# Processing city: 5102637
# Processing city: 5102678
# Processing city: 5102686
# Processing city: 5102694
# Processing city: 5102702
# Processing city: 5102793
# Processing city: 5102850
# Processing city: 5103007
# Processing city: 5103056
# Processing city: 5103106
# Processing city: 5103205
# Processing city: 5103254
# Processing city: 5103304
# Processing city: 5103353
# Processing city: 5103361
# Processing city: 5103379
# Processing city: 5103403
# Processing city: 5103437
# Processing city: 5103452
# Processing city: 5103502
# Processing city: 5103601
# Processing city: 5103700
# Processing city: 5103809
# Processing city: 5103858
# Processing city: 5103908
# Processing city: 5103957
# Processing city: 5104104
# Processing city: 5104203
# Processing city: 5104500
# Processing city: 5104526
# Processing city: 5104542
# Processing city: 5104559
# Processing city: 5104609
# Processing city: 5104807
# Processing city: 5104906
# Processing city: 5105002
# Processing city: 5105101
# Processing city: 5105150
# Processing city: 5105176
# Processing city: 5105200
# Processing city: 5105234
# Processing city: 5105259
# Processing city: 5105309
# Processing city: 5105507
# Processing city: 5105580
# Processing city: 5105606
# Processing city: 5105622
# Processing city: 5105903
# Processing city: 5106000
# Processing city: 5106109
# Processing city: 5106158
# Processing city: 5106174
# Processing city: 5106182
# Processing city: 5106190
# Processing city: 5106208
# Processing city: 5106216
# Processing city: 5106224
# Processing city: 5106232
# Processing city: 5106240
# Processing city: 5106257
# Processing city: 5106265
# Processing city: 5106273
# Processing city: 5106281
# Processing city: 5106299
# Processing city: 5106307
# Processing city: 5106315
# Processing city: 5106372
# Processing city: 5106422
# Processing city: 5106455
# Processing city: 5106505
# Processing city: 5106653
# Processing city: 5106703
# Processing city: 5106752
# Processing city: 5106778
# Processing city: 5106802
# Processing city: 5106828
# Processing city: 5106851
# Processing city: 5107008
# Processing city: 5107040
# Processing city: 5107065
# Processing city: 5107107
# Processing city: 5107156
# Processing city: 5107180
# Processing city: 5107198
# Processing city: 5107206
# Processing city: 5107248
# Processing city: 5107263
# Processing city: 5107297
# Processing city: 5107305
# Processing city: 5107354
# Processing city: 5107404
# Processing city: 5107578
# Processing city: 5107602
# Processing city: 5107701
# Processing city: 5107743
# Processing city: 5107750
# Processing city: 5107768
# Processing city: 5107776
# Processing city: 5107792
# Processing city: 5107800
# Processing city: 5107859
# Processing city: 5107875
# Processing city: 5107883
# Processing city: 5107909
# Processing city: 5107925
# Processing city: 5107941
# Processing city: 5107958
# Processing city: 5108006
# Processing city: 5108055
# Processing city: 5108105
# Processing city: 5108204
# Processing city: 5108303
# Processing city: 5108352
# Processing city: 5108402
# Processing city: 5108501
# Processing city: 5108600
# Processing city: 5108808
# Processing city: 5108857
# Processing city: 5108907
# Processing city: 5108956
# Processing city: 5200050
# Processing city: 5200100
# Processing city: 5200134
# Processing city: 5200159
# Processing city: 5200175
# Processing city: 5200209
# Processing city: 5200258
# Processing city: 5200308
# Processing city: 5200506
# Processing city: 5200555
# Processing city: 5200605
# Processing city: 5200803
# Processing city: 5200829
# Processing city: 5200852
# Processing city: 5200902
# Processing city: 5201108
# Processing city: 5201207
# Processing city: 5201306
# Processing city: 5201405
# Processing city: 5201454
# Processing city: 5201504
# Processing city: 5201603
# Processing city: 5201702
# Processing city: 5201801
# Processing city: 5202155
# Processing city: 5202353
# Processing city: 5202502
# Processing city: 5202601
# Processing city: 5202809
# Processing city: 5203104
# Processing city: 5203203
# Processing city: 5203302
# Processing city: 5203401
# Processing city: 5203500
# Processing city: 5203559
# Processing city: 5203575
# Processing city: 5203609
# Processing city: 5203807
# Processing city: 5203906
# Processing city: 5203939
# Processing city: 5203962
# Processing city: 5204003
# Processing city: 5204102
# Processing city: 5204201
# Processing city: 5204250
# Processing city: 5204300
# Processing city: 5204409
# Processing city: 5204508
# Processing city: 5204557
# Processing city: 5204607
# Processing city: 5204656
# Processing city: 5204706
# Processing city: 5204805
# Processing city: 5204854
# Processing city: 5204904
# Processing city: 5204953
# Processing city: 5205000
# Processing city: 5205059
# Processing city: 5205109
# Processing city: 5205208
# Processing city: 5205307
# Processing city: 5205406
# Processing city: 5205455
# Processing city: 5205471
# Processing city: 5205497
# Processing city: 5205513
# Processing city: 5205521
# Processing city: 5205703
# Processing city: 5205802
# Processing city: 5205901
# Processing city: 5206206
# Processing city: 5206305
# Processing city: 5206404
# Processing city: 5206503
# Processing city: 5206602
# Processing city: 5206701
# Processing city: 5206800
# Processing city: 5206909
# Processing city: 5207105
# Processing city: 5207253
# Processing city: 5207352
# Processing city: 5207402
# Processing city: 5207501
# Processing city: 5207535
# Processing city: 5207600
# Processing city: 5207808
# Processing city: 5207907
# Processing city: 5208004
# Processing city: 5208103
# Processing city: 5208152
# Processing city: 5208301
# Processing city: 5208400
# Processing city: 5208509
# Processing city: 5208608
# Processing city: 5208707
# Processing city: 5208806
# Processing city: 5208905
# Processing city: 5209101
# Processing city: 5209150
# Processing city: 5209200
# Processing city: 5209291
# Processing city: 5209408
# Processing city: 5209457
# Processing city: 5209606
# Processing city: 5209705
# Processing city: 5209804
# Processing city: 5209903
# Processing city: 5209937
# Processing city: 5209952
# Processing city: 5210000
# Processing city: 5210109
# Processing city: 5210158
# Processing city: 5210208
# Processing city: 5210307
# Processing city: 5210406
# Processing city: 5210562
# Processing city: 5210604
# Processing city: 5210802
# Processing city: 5210901
# Processing city: 5211008
# Processing city: 5211206
# Processing city: 5211305
# Processing city: 5211404
# Processing city: 5211503
# Processing city: 5211602
# Processing city: 5211701
# Processing city: 5211800
# Processing city: 5211909
# Processing city: 5212006
# Processing city: 5212055
# Processing city: 5212105
# Processing city: 5212204
# Processing city: 5212253
# Processing city: 5212303
# Processing city: 5212501
# Processing city: 5212600
# Processing city: 5212709
# Processing city: 5212808
# Processing city: 5212907
# Processing city: 5212956
# Processing city: 5213004
# Processing city: 5213053
# Processing city: 5213087
# Processing city: 5213103
# Processing city: 5213400
# Processing city: 5213509
# Processing city: 5213707
# Processing city: 5213756
# Processing city: 5213772
# Processing city: 5213806
# Processing city: 5213855
# Processing city: 5213905
# Processing city: 5214002
# Processing city: 5214051
# Processing city: 5214101
# Processing city: 5214408
# Processing city: 5214507
# Processing city: 5214606
# Processing city: 5214705
# Processing city: 5214804
# Processing city: 5214838
# Processing city: 5214861
# Processing city: 5214879
# Processing city: 5214903
# Processing city: 5215009
# Processing city: 5215207
# Processing city: 5215231
# Processing city: 5215256
# Processing city: 5215306
# Processing city: 5215405
# Processing city: 5215504
# Processing city: 5215603
# Processing city: 5215652
# Processing city: 5215702
# Processing city: 5215801
# Processing city: 5215900
# Processing city: 5216007
# Processing city: 5216304
# Processing city: 5216403
# Processing city: 5216452
# Processing city: 5216809
# Processing city: 5216908
# Processing city: 5217104
# Processing city: 5217203
# Processing city: 5217302
# Processing city: 5217401
# Processing city: 5217609
# Processing city: 5217708
# Processing city: 5218003
# Processing city: 5218052
# Processing city: 5218102
# Processing city: 5218300
# Processing city: 5218391
# Processing city: 5218508
# Processing city: 5218607
# Processing city: 5218706
# Processing city: 5218789
# Processing city: 5218805
# Processing city: 5218904
# Processing city: 5219001
# Processing city: 5219100
# Processing city: 5219209
# Processing city: 5219258
# Processing city: 5219308
# Processing city: 5219357
# Processing city: 5219407
# Processing city: 5219456
# Processing city: 5219506
# Processing city: 5219605
# Processing city: 5219704
# Processing city: 5219712
# Processing city: 5219738
# Processing city: 5219753
# Processing city: 5219803
# Processing city: 5219902
# Processing city: 5220009
# Processing city: 5220058
# Processing city: 5220108
# Processing city: 5220157
# Processing city: 5220207
# Processing city: 5220264
# Processing city: 5220280
# Processing city: 5220405
# Processing city: 5220454
# Processing city: 5220504
# Processing city: 5220603
# Processing city: 5220686
# Processing city: 5220702
# Processing city: 5221007
# Processing city: 5221080
# Processing city: 5221197
# Processing city: 5221304
# Processing city: 5221403
# Processing city: 5221452
# Processing city: 5221502
# Processing city: 5221551
# Processing city: 5221577
# Processing city: 5221601
# Processing city: 5221700
# Processing city: 5221809
# Processing city: 5221858
# Processing city: 5221908
# Processing city: 5222005
# Processing city: 5222054
# Processing city: 5222203
# Processing city: 5222302
# Processing city: 5300108

# %%
# --- Combine all cities into one DataFrame ---
results_df = pd.concat(lst_results, ignore_index=True)

# %%
results_df
# Out:
#         neighbour  triggered  total_index_events         P  \
# 0         1100023          9                  40  0.225000
# 1         1100049         11                  40  0.275000
# 2         1100122         11                  40  0.275000
# 3         1100148         25                  40  0.625000
# 4         1100189         14                  40  0.350000
# ...           ...        ...                 ...       ...
# 505273    5217609         18                  31  0.580645
# 505274    5218805         26                  31  0.838710
# 505275    5219753         26                  31  0.838710
# 505276    5221601         25                  31  0.806452
# 505277    5221858         28                  31  0.903226
#
#         average_neighbour_level_probability  \
# 0                                  0.328846
# 1                                  0.328846
# 2                                  0.328846
# 3                                  0.328846
# 4                                  0.328846
# ...                                     ...
# 505273                             0.760864
# 505274                             0.760864
# 505275                             0.760864
# 505276                             0.760864
# 505277                             0.760864
#
#         prob_at_least_one_neighbour_triggered  k  origin_city
# 0                                       0.975  0      1100015
# 1                                       0.975  0      1100015
# 2                                       0.975  0      1100015
# 3                                       0.975  0      1100015
# 4                                       0.975  0      1100015
# ...                                       ... ..          ...
# 505273                                  1.000  5      5300108
# 505274                                  1.000  5      5300108
# 505275                                  1.000  5      5300108
# 505276                                  1.000  5      5300108
# 505277                                  1.000  5      5300108
#
# [505278 rows x 8 columns]

# %%
results_df.to_parquet('/Users/julianeoliveira/Downloads/prob_spread.parquet')

# %% [markdown]
# # Probabilidade de espalhamento em uma janela de tempo, ao observar o aviso em uma cidade

# %%
def compute_spread_probability(df, index_city, neighbours, start_week=None):
    """
    Compute empirical spread probability from one index city to its neighbours.

    Parameters
    ----------
    df : pd.DataFrame
        Rows = city codes, columns = week identifiers (e.g., '2023-34'), values = 0/1.
    index_city : str or int
        City code of the source (index) city.
    neighbours : list
        List of city codes (neighbours in the network).
    start_week : str, optional
        Week when the index city first had a warning. If None, inferred automatically.
    """

    # Ensure week columns are sorted
    df = df.copy()
    df = df[sorted(df.columns, key=lambda x: int(x.split('-')[1]))]

    # Get index city signal
    signal = df.loc[index_city]

    # Find start week if not given
    if start_week is None:
        start_week = signal[signal == 1].index[0]
    start_idx = list(df.columns).index(start_week)

    # For each neighbour, find delay to first 1 after start_week
    delays = []
    for n in neighbours:
        neigh_signal = df.loc[n].iloc[start_idx + 1:]
        first_1 = np.argmax(neigh_signal.values == 1) if 1 in neigh_signal.values else None
        if first_1 is not None and neigh_signal.values[first_1] == 1:
            delays.append(first_1 + 1)  # +1 because indices start at 0
        else:
            delays.append(np.nan)

    # Build results dataframe
    res = pd.DataFrame({
        'city': neighbours,
        'delay_weeks': delays
    })

    # Empirical cumulative probability of spread
    valid_delays = res['delay_weeks'].dropna().astype(int)
    max_delay = valid_delays.max() if not valid_delays.empty else 0
    weeks = np.arange(1, max_delay + 1)
    prob_cum = [np.mean(valid_delays <= k) for k in weeks]

    # Plot
    plt.figure(figsize=(6, 4))
    plt.plot(weeks, prob_cum, marker='o')
    plt.xlabel("Weeks since index warning")
    plt.ylabel("Cumulative probability of spread")
    plt.title(f"Spread from {index_city}")
    plt.grid(True)
    plt.show()

    return res, pd.DataFrame({'weeks': weeks, 'P(spread)': prob_cum})

# %%
#set_muni[set_muni['Aviso AESOP'] == 1]

# %%
# seleciona uma semana onde observamos um aviso no município selecionado (origem) e verificamos quando aparece aviso 
# nos destinos

data2 = data1[(data1.year_week >= '2023-25') & (data1.year_week <= '2023-33')][['co_ibge7','year_week','Aviso AESOP']]

# %%
data2 = data1[['co_ibge7','year_week','Aviso AESOP']]

# %%
table = pd.pivot_table(data2, values='Aviso AESOP', index=['co_ibge7'],
                   columns=['year_week'], aggfunc="sum")

# %%
#table

# %%
index_city = city
neighbours = list(set_muni_mob.cod_ibge_muni.unique())#[1100023,1100049,1100122,1100189,1100205,1100254,1100288,1100296]

res, prob_curve = compute_spread_probability(table, index_city, neighbours)

# %%
print(res)
print(prob_curve)
# Out:
#       city  delay_weeks
# 0  1100023            8
# 1  1100049            2
# 2  1100122            2
# 3  1100189            3
# 4  1100205            8
# 5  1100254            2
# 6  1100288            2
# 7  1100296           23
#     weeks  P(spread)
# 0       1      0.000
# 1       2      0.500
# 2       3      0.625
# 3       4      0.625
# 4       5      0.625
# 5       6      0.625
# 6       7      0.625
# 7       8      0.875
# 8       9      0.875
# 9      10      0.875
# 10     11      0.875
# 11     12      0.875
# 12     13      0.875
# 13     14      0.875
# 14     15      0.875
# 15     16      0.875
# 16     17      0.875
# 17     18      0.875
# 18     19      0.875
# 19     20      0.875
# 20     21      0.875
# 21     22      0.875
# 22     23      1.000

# %%
def conditional_spread_prob(df, index_city, neighbours, k=1):
    """
    Compute P(neighbour has >=1 warning within k weeks starting at same week as index warning),
    aggregated over all index warnings observed in df.
    
    Parameters
    ----------
    df : DataFrame (rows=cities indexed by code, cols=week labels)
    index_city : city code
    neighbours : list of neighbour city codes
    k : int, window size in weeks (k=0 means same week only; k=1 means same week or next week)
    """
    weeks = list(df.columns)
    n_weeks = len(weeks)
    
    # Find all weeks where index city has a warning (=1)
    index_weeks = [i for i,w in enumerate(weeks) if df.loc[index_city, w] == 1]
    if not index_weeks:
        return None
    
    # For each neighbour, count how many index-week events were followed by at least one warning
    results = []
    for n in neighbours:
        triggered = 0
        total = 0
        for iw in index_weeks:
            # define window [iw, iw + k] inclusive, but not beyond available weeks
            start = iw
            end = min(iw + k, n_weeks - 1)
            total += 1
            # check if neighbour has any 1 in that window
            window_weeks = weeks[start:end+1]
            if df.loc[n, window_weeks].sum() > 0:
                triggered += 1
        prob = triggered / total if total > 0 else np.nan
        results.append({'neighbour': n, 'triggered': triggered, 'total_index_events': total, 'P': prob})
    
    res_df = pd.DataFrame(results).set_index('neighbour')
    # Aggregate across neighbours: probability that *a random neighbour* is triggered
    agg_P = res_df['P'].mean()
    # Probability that at least one neighbour is triggered for each index event
    # compute per index event whether any neighbour had 1 in window, then average
    any_trigger_per_event = []
    for iw in index_weeks:
        start = iw
        end = min(iw + k, n_weeks - 1)
        window_weeks = weeks[start:end+1]
        # check across all neighbours for that index event
        any_trigger = (df.loc[neighbours, window_weeks].sum(axis=0).sum() > 0)
        any_trigger_per_event.append(1 if any_trigger else 0)
    prob_any_neighbour = np.mean(any_trigger_per_event)
    
    return res_df, agg_P, prob_any_neighbour, index_weeks

# %%
# Compute for k = 0 (same week), k = 1 (same or next week), and k = 2
outputs = {}
for k in [0,1,2]:
    res_df, agg_P, prob_any_neighbour, index_weeks = conditional_spread_prob(table, index_city, neighbours, k=k)
    outputs[k] = {'per_neighbour': res_df, 'avg_P_neighbour': agg_P, 'P_any_neighbour': prob_any_neighbour, 'index_weeks': index_weeks}

# Display results
for k, out in outputs.items():
    print(f"\n=== Window k={k} (same week + next {k} weeks) ===")
    print("Index city warning weeks (positions):", out['index_weeks'])
    display(out['per_neighbour'])  # Using display so DataFrame looks nice in the notebook
    print(f"Average neighbour-level probability P = {out['avg_P_neighbour']:.3f}")
    print(f"Probability at least one neighbour triggered given an index event = {out['P_any_neighbour']:.3f}")
# Out:
# === Window k=0 (same week + next 0 weeks) ===
# Index city warning weeks (positions): [35, 36, 44, 45, 46, 47, 48, 49, 50, 51, 53, 54, 55, 56, 57, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 79, 80, 81, 87, 88, 101, 103, 112, 116, 117, 126, 141]
#            triggered  total_index_events      P
# neighbour
# 1100023            9                  40  0.225
# 1100049           11                  40  0.275
# 1100122           11                  40  0.275
# 1100189           14                  40  0.350
# 1100205           13                  40  0.325
# 1100254           13                  40  0.325
# 1100288           17                  40  0.425
# 1100296           16                  40  0.400
# Average neighbour-level probability P = 0.325
# Probability at least one neighbour triggered given an index event = 0.925
#
# === Window k=1 (same week + next 1 weeks) ===
# Index city warning weeks (positions): [35, 36, 44, 45, 46, 47, 48, 49, 50, 51, 53, 54, 55, 56, 57, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 79, 80, 81, 87, 88, 101, 103, 112, 116, 117, 126, 141]
#            triggered  total_index_events      P
# neighbour
# 1100023           14                  40  0.350
# 1100049           21                  40  0.525
# 1100122           16                  40  0.400
# 1100189           19                  40  0.475
# 1100205           22                  40  0.550
# 1100254           21                  40  0.525
# 1100288           25                  40  0.625
# 1100296           22                  40  0.550
# Average neighbour-level probability P = 0.500
# Probability at least one neighbour triggered given an index event = 0.975
#
# === Window k=2 (same week + next 2 weeks) ===
# Index city warning weeks (positions): [35, 36, 44, 45, 46, 47, 48, 49, 50, 51, 53, 54, 55, 56, 57, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 79, 80, 81, 87, 88, 101, 103, 112, 116, 117, 126, 141]
#            triggered  total_index_events      P
# neighbour
# 1100023           20                  40  0.500
# 1100049           25                  40  0.625
# 1100122           22                  40  0.550
# 1100189           23                  40  0.575
# 1100205           27                  40  0.675
# 1100254           27                  40  0.675
# 1100288           28                  40  0.700
# 1100296           26                  40  0.650
# Average neighbour-level probability P = 0.619
# Probability at least one neighbour triggered given an index event = 1.000
