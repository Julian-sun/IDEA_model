# %% [markdown]
# # Here we aim to implement the method of EVI (Epidemic Volatility Index) in python

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import math
import seaborn as sns
import pyarrow as pa
import pyarrow.parquet as pq
import itertools

# %% [markdown]
# # Read the data

# %%
link = '/opt/storage/refined/aesop/visualization/cleaned_aesop_22_11_2023_variable2.parquet'


df = pd.read_parquet(link, engine='pyarrow')

# %%
df.head()
# Out:
#     co_uf     nm_uf  co_ibge  co_ibge7           nm_municipio  atend_ivas  \
# 27     11  Rondônia   110001   1100015  Alta Floresta D'Oeste           9
# 15     11  Rondônia   110001   1100015  Alta Floresta D'Oeste          16
# 21     11  Rondônia   110001   1100015  Alta Floresta D'Oeste          15
# 18     11  Rondônia   110001   1100015  Alta Floresta D'Oeste          17
# 16     11  Rondônia   110001   1100015  Alta Floresta D'Oeste          11
#
#     atend_totais   ano  epiweek year_week year_week_ts  ra_atend_ivas  \
# 27           412  2017        1   2017-01   2017-01-02           2.18
# 15           712  2017        2   2017-02   2017-01-09           2.25
# 21           525  2017        3   2017-03   2017-01-16           2.86
# 18           651  2017        4   2017-04   2017-01-23           2.61
# 16           680  2017        5   2017-05   2017-01-30           1.62
#
#     ra_atend_ivas_ma  gr_ra_atend_ivas_ma  ma_atend_indicators    pop
# ...

# %% [markdown]
# # Simple EVI implementation

# %% [markdown]
# EVI is calculated for a rolling window of time series epidemic data (i.e. the number of new cases per week). At each step, the observations within the window are obtained by shifting the window forward over the time series data one observation at a time.
#
# Let $x_i=\left\{x_1,\;x_2,...,x_n\right\}$ be a time series of length N. The rolling window size - that is the number of consecutive observations per rolling window - is m. With $0<m\le m_{max}$ and $0<m_{max}\le N$, there are  $t = N - m + 1$ consecutive rolling windows.
#
# At each of the t steps, EVI uses the standard deviation $\left(s_t\right)$ of the newly reported cases $\left(y_{j_t}=\left\{y_{1_t},\;y_{2_t},...\;,y_{m_t}\right\}\right)$ within the specified m
#
# $$s_t=\sqrt{\frac{1}{m}\sum_{i_t=1}^{m}\left(x_{i_t}-{\overline{x}}_t\right)^2}$$
#
# with $\overline{x_t}$ the mean of the $t^{th}$ window. Subsequently, EVI is calculated as the relative change of $\left(s_t\right)$ between two consecutive rolling windows:
#
# $$EVI_{t-1,t}=\frac{s_t-s_{t-1}}{s_{t-1}}$$
#
# We expect an increase in the future number of cases, if $EVI_{t-1,t}$ exceeds a threshold c $\left(c\in\left[0,1\right]\right)$ and the observed cases at time point t,$\left(y_t\right)$ are higher than the average of the reported cases in the previous week:
#
# $$Ind_{EVI_{t-1,t}}=\left\{\begin{matrix} 1 & if & E V I_{t-1,t}\geq c \ and \  y_t\geq{\overline{\mu}}_{t:t-7}\\
#                                           0 & otherwise\\
#                                           \end{matrix}\right.$$

# %%
def func(m, series,r_a,mu,c):
    "This function calculates the EVIt-1,t which can be further used for the creation of the EVI ind."
    "The imput funcion is: m: the rolling window size; serie: the time series where we desire to employ our result;"
    "r_a: the lag for the mooving average to be applied to the series;" 
    "mu: the window for posterior mean (used in the original method as 7)"
    "c1 and c2 are treshold limits"
    
    tseries = pd.Series(series).rolling(window=r_a).mean()
    
    # Obtain the rolling windows of size m and calculate their standard deviation
    #lst_windows = []
    std_windows = []
    for i in range(0,len(tseries) - m +1):
        win = tseries[0+i:m+i]
    
        #lst_windows.append(win)
        std_windows.append(win.std())
        
    # Calculate EVIt-1,t
        
    evi_t1_t = round((pd.Series(std_windows) - pd.Series(std_windows).shift())/ abs(pd.Series(std_windows).shift()),2)
    
    evi_t1_t_2 =  [0] * (m-1)  + evi_t1_t.to_list()
    
    # Obtain the mean of the last 7 points

    mean_windows = []
    

    for i in range(0,len(tseries) - mu +1):
        win = series[0+i:mu+i]
        
    
        mean_windows.append(win.mean())
        
        
    mu_ = [0] * (mu-1)  + mean_windows
    
    
    # Create a dataframe with the results
    d = {'series': series, 'tseries': tseries, 'evi_t1_t': evi_t1_t_2,'mu':mu_}

    data = pd.DataFrame(data=d)
    
    data.evi_t1_t = data.evi_t1_t.fillna(0)
    
    data.mu = round(data.mu,0)
    
    data.loc[(data['series'] < 0.75*data['mu']),'cat_mu'] = 0
    data.loc[((data['series'] >= 0.75*data['mu']) & (data['series'] < data['mu'])),'cat_mu'] = 0.5
    data.loc[(data['series'] >= data['mu']),'cat_mu'] = 1

    data.loc[(data['evi_t1_t'] < c),'cat_evi'] = 0
    #data.loc[(data['evi_t1_t'] >= c1) & (data['evi_t1_t'] < c2),'cat_evi'] = 0.5
    data.loc[(data['evi_t1_t'] >= c),'cat_evi'] = 1

    data.loc[(data['cat_evi'] == 0),'ind'] = 0
    data.loc[(data['cat_evi'] == 1) & (data['cat_mu'] == 0),'ind'] = 0
    data.loc[(data['cat_evi'] == 1) & (data['cat_mu'] == 0.5),'ind'] = 0
    #data.loc[(data['cat_evi'] == 0) & (data['cat_mu'] == 1),'ind'] = 0.5
    data.loc[(data['cat_evi'] == 1) & (data['cat_mu'] == 1),'ind'] = 1
    
    data.loc[(data['cat_mu'] == 0) | (data['evi_t1_t'] < 0) ,'ind_2'] = 0
    #data.loc[(data['evi_t1_t'] = 0) & (data['cat_mu'] == 1),'ind_2'] = 0
    data.loc[(data['evi_t1_t'] >= 0) & (data['evi_t1_t'] <= c) & (data['cat_mu'] >= 0.5),'ind_2'] = 0.5
    data.loc[(data['evi_t1_t'] > c) & (data['cat_mu'] == 0.5),'ind_2'] = 0.5
    data.loc[(data['evi_t1_t'] > c) & (data['cat_mu'] == 1),'ind_2'] = 1
    
    return data #lst_windows, std_windows

# %%
#df[df.nm_municipio == 'Itapetinga']

# %%
code = 2916401

set_muni = df[df.co_ibge7 == code]

set_muni
# Out:
#         co_uf  nm_uf  co_ibge  co_ibge7 nm_municipio  atend_ivas  \
# 105086     29  Bahia   291640   2916401   Itapetinga          18
# 105066     29  Bahia   291640   2916401   Itapetinga          13
# 105045     29  Bahia   291640   2916401   Itapetinga          26
# 105067     29  Bahia   291640   2916401   Itapetinga          30
# 105072     29  Bahia   291640   2916401   Itapetinga          21
# ...       ...    ...      ...       ...          ...         ...
# 92946      29  Bahia   291640   2916401   Itapetinga          79
# 92927      29  Bahia   291640   2916401   Itapetinga         103
# 92929      29  Bahia   291640   2916401   Itapetinga          65
# 92930      29  Bahia   291640   2916401   Itapetinga          96
# 92925      29  Bahia   291640   2916401   Itapetinga         114
#
#         atend_totais   ano  epiweek year_week year_week_ts  ra_atend_ivas  \
# 105086            58  2017        1   2017-01   2017-01-02          31.03
# ...

# %%
#func(m, serie,r_a,mu,c1,c2)
dtf = func(5,set_muni.atend_ivas.to_numpy(),1,8,0.2)

# %%
dtf
# Out:
#      series  tseries  evi_t1_t    mu  cat_mu  cat_evi  ind  ind_2
# 0        18     18.0      0.00   0.0     1.0      0.0  0.0    0.5
# 1        13     13.0      0.00   0.0     1.0      0.0  0.0    0.5
# 2        26     26.0      0.00   0.0     1.0      0.0  0.0    0.5
# 3        30     30.0      0.00   0.0     1.0      0.0  0.0    0.5
# 4        21     21.0      0.00   0.0     1.0      0.0  0.0    0.5
# ..      ...      ...       ...   ...     ...      ...  ...    ...
# 354      79     79.0     -0.03  71.0     1.0      0.0  0.0    0.0
# 355     103    103.0      0.09  72.0     1.0      0.0  0.0    0.5
# 356      65     65.0      0.02  74.0     0.5      0.0  0.0    0.5
# 357      96     96.0     -0.02  76.0     1.0      0.0  0.0    0.0
# 358     114    114.0     -0.15  84.0     1.0      0.0  0.0    0.0
#
# [359 rows x 8 columns]

# %%
def plot_func(dtf,c):
    
    x = list(range(0, len(dtf)))
    
    dtf = dtf.assign(Days = x)
    
    fig = plt.figure(figsize =(15, 3))
    plt.plot(x, dtf.series)
    plt.plot(x, dtf.tseries,'-o')
    plt.plot(x, dtf.mu,linestyle = '--',label = 'mu')
    #plt.plot(x, 0.75*dtf.mu,linestyle = '--',label = '0.75mu')
    plt.legend()
    plt.xticks(rotation=90)
    plt.tight_layout()
    
    # plot2
    
    fig = plt.figure(figsize =(15, 3))
    plt.plot(x, dtf.evi_t1_t)
    plt.axhline(y = c, color = 'y', linestyle = '--', label='c')
    #plt.axhline(y = c2, color = 'r', linestyle = '--', label='c2')
    plt.legend()
    plt.ylim([-1,1])
    plt.xlabel('Days')
    plt.ylabel('EVI_t-1,t')
    plt.xticks(rotation=90)
    plt.tight_layout()
    
    # plot3
    
    fig = plt.figure(figsize =(15, 4))
    sns.scatterplot(x = "Days", y = "series", data = dtf, hue = "ind",
                palette = "RdYlBu_r") #gist_gray, flare,RdYlBu_r
    
    #plot4
    fig = plt.figure(figsize =(15, 4))
    sns.scatterplot(x = "Days", y = "series", data = dtf, hue = "ind_2",
                palette = "RdYlBu_r") #gist_gray, flare,RdYlBu_r
    plt.plot(x, dtf.mu,linestyle = '--',label = 'mu')
    
    #dtf = dtf.assign(CasesCum=dtf['mov_av'].cumsum())
    #dtf = dtf.assign(CasesCumLog =np.log(dtf['CasesCum']))
    #dtf = dtf.assign(CasesLog =np.log(dtf['mov_av']))

    #sns.scatterplot(x = "Days", y = "CasesCumLog", data = dtf, hue = "ind",
    #            palette = "RdYlBu_r")

# %%
plot_func(dtf,0.2)

# %%
#dtf[dtf.ind_2 == 0.5]     #[(dtf.cat_mu == 0.5)&(dtf.evi_t1_t >0)]

# %% [markdown]
# # Run the method for all municipalities and save data with standard format

# %%
dtf
# Out:
#      series  tseries  evi_t1_t    mu  cat_mu  cat_evi  ind  ind_2
# 0        18     18.0      0.00   0.0     1.0      0.0  0.0    0.5
# 1        13     13.0      0.00   0.0     1.0      0.0  0.0    0.5
# 2        26     26.0      0.00   0.0     1.0      0.0  0.0    0.5
# 3        30     30.0      0.00   0.0     1.0      0.0  0.0    0.5
# 4        21     21.0      0.00   0.0     1.0      0.0  0.0    0.5
# ..      ...      ...       ...   ...     ...      ...  ...    ...
# 354      79     79.0     -0.03  71.0     1.0      0.0  0.0    0.0
# 355     103    103.0      0.09  72.0     1.0      0.0  0.0    0.5
# 356      65     65.0      0.02  74.0     0.5      0.0  0.0    0.5
# 357      96     96.0     -0.02  76.0     1.0      0.0  0.0    0.0
# 358     114    114.0     -0.15  84.0     1.0      0.0  0.0    0.0
#
# [359 rows x 8 columns]

# %%
lst_dfs = []

for code in df.co_ibge7.unique():

    set_muni = df[df.co_ibge7 == code]

    dtf = func(5,set_muni.atend_ivas.to_numpy(),2,8,0.2) #MUDANÇA AQUI na media movel 
    
    set_muni = set_muni.reset_index()
    set_muni = set_muni.assign(tseries = dtf['tseries'])
    set_muni = set_muni.assign(evi_t1_t = dtf['evi_t1_t'])
    set_muni = set_muni.assign(mu = dtf['mu'])
    set_muni = set_muni.assign(ind = dtf['ind'])
    set_muni = set_muni.assign(ind2 = dtf['ind_2'])
    set_muni = set_muni.assign(exc = set_muni['atend_ivas'] - set_muni['mu'])
    set_muni['exc'][set_muni['exc'] < 0] = 0
    
    lst_dfs.append(set_muni)
# Out:
# /tmp/ipykernel_2200891/1367331805.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_muni['exc'][set_muni['exc'] < 0] = 0
# /tmp/ipykernel_2200891/1367331805.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_muni['exc'][set_muni['exc'] < 0] = 0
# /tmp/ipykernel_2200891/1367331805.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set_muni['exc'][set_muni['exc'] < 0] = 0
# ...

# %%
lst_dfs[0]
# Out:
#      index  co_uf     nm_uf  co_ibge  co_ibge7           nm_municipio  \
# 0       27     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 1       15     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 2       21     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 3       18     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 4       16     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# ..     ...    ...       ...      ...       ...                    ...
# 354     21     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 355     13     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 356     38     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 357      1     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 358     29     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
#
#      atend_ivas  atend_totais   ano  epiweek  ... ra_atend_ivas_ma  \
# ...

# %%
def plot_func2(dtf,c):
    
    #x = list(range(0, len(dtf)))
    x = dtf.year_week_ts
    #dtf = dtf.assign(Days = x)
    
    fig = plt.figure(figsize =(15, 3))
    plt.plot(x, dtf.atend_ivas)
    plt.plot(x, dtf.tseries,'-o')
    plt.plot(x, dtf.mu,linestyle = '--',label = 'mu')
    #plt.plot(x, 0.75*dtf.mu,linestyle = '--',label = '0.75mu')
    plt.legend()
    plt.xticks(rotation=90)
    plt.tight_layout()
    
    # plot2
    
    fig = plt.figure(figsize =(15, 3))
    plt.plot(x, dtf.evi_t1_t)
    plt.axhline(y = c, color = 'y', linestyle = '--', label='c')
    #plt.axhline(y = c2, color = 'r', linestyle = '--', label='c2')
    plt.legend()
    plt.ylim([-1,1])
    plt.xlabel('year_week_ts')
    plt.ylabel('EVI_t-1,t')
    plt.xticks(rotation=90)
    plt.tight_layout()
    
    # plot3
    
    fig = plt.figure(figsize =(15, 4))
    sns.scatterplot(x = "year_week_ts", y = "tseries", data = dtf, hue = "ind",
                palette = "RdYlBu_r") #gist_gray, flare,RdYlBu_r
    plt.xticks(rotation=90)
    
    #plot4
        
    fig = plt.figure(figsize =(15, 4))
    sns.scatterplot(x = "year_week_ts", y = "tseries", data = dtf, hue = "ind2",
                palette = "RdYlBu_r") #gist_gray, flare,RdYlBu_r
    plt.xticks(rotation=90)
    
    #dtf = dtf.assign(CasesCum=dtf['mov_av'].cumsum())
    #dtf = dtf.assign(CasesCumLog =np.log(dtf['CasesCum']))
    #dtf = dtf.assign(CasesLog =np.log(dtf['mov_av']))

    #sns.scatterplot(x = "Days", y = "CasesCumLog", data = dtf, hue = "ind",
    #            palette = "RdYlBu_r")

# %%
plot_func2(lst_dfs[0],0.2)

# %%
df_final = pd.concat(lst_dfs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999630 entries, 27 to 256200
# Data columns (total 16 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   co_uf                int64
#  1   nm_uf                string
#  2   co_ibge              int64
#  3   co_ibge7             int64
#  4   nm_municipio         string
#  5   atend_ivas           int64
#  6   atend_totais         int64
#  7   ano                  int64
#  8   epiweek              int64
#  9   year_week            object
#  10  year_week_ts         datetime64[ns]
#  11  ra_atend_ivas        float64
#  12  ra_atend_ivas_ma     float64
#  13  gr_ra_atend_ivas_ma  float64
#  14  ma_atend_indicators  int64
#  15  pop                  int64
# dtypes: datetime64[ns](1), float64(3), int64(9), object(1), string(2)
# memory usage: 259.4+ MB

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999630 entries, 0 to 358
# Data columns (total 23 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   index                int64
#  1   co_uf                int64
#  2   nm_uf                string
#  3   co_ibge              int64
#  4   co_ibge7             int64
#  5   nm_municipio         string
#  6   atend_ivas           int64
#  7   atend_totais         int64
#  8   ano                  int64
#  9   epiweek              int64
#  10  year_week            object
#  11  year_week_ts         datetime64[ns]
#  12  ra_atend_ivas        float64
#  13  ra_atend_ivas_ma     float64
#  14  gr_ra_atend_ivas_ma  float64
#  15  ma_atend_indicators  int64
#  16  pop                  int64
#  17  tseries              float64
#  18  evi_t1_t             float64
#  19  mu                   float64
#  20  ind                  float64
#  21  ind2                 float64
#  22  exc                  float64
# ...

# %%
df_final.head()
# Out:
#    index  co_uf     nm_uf  co_ibge  co_ibge7           nm_municipio  \
# 0     27     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 1     15     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 2     21     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 3     18     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 4     16     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
#
#    atend_ivas  atend_totais   ano  epiweek  ... ra_atend_ivas_ma  \
# 0           9           412  2017        1  ...             0.00
# 1          16           712  2017        2  ...             0.00
# 2          15           525  2017        3  ...             0.00
# 3          17           651  2017        4  ...             2.48
# 4          11           680  2017        5  ...             2.34
#
#   gr_ra_atend_ivas_ma  ma_atend_indicators    pop  tseries  evi_t1_t   mu  \
# 0                0.00                    0  25437      NaN       0.0  0.0
# ...

# %% [markdown]
# # Analisis of output

# %% [markdown]
# ## Analysis of inf values

# %%
df_final.evi_t1_t.describe()
# Out:
# count    1999630.00
# mean            inf
# std             NaN
# min           -1.00
# 25%           -0.17
# 50%            0.00
# 75%            0.20
# max             inf
# Name: evi_t1_t, dtype: float64

# %%
#df_final[df_final.evi_t1_t.isnan()]

#df_final[isnull(df_final['evi_t1_t'])]

inf_df = df_final[(df_final == np.inf).any(axis=1)]
inf_df
# Out:
#       index  co_uf             nm_uf  co_ibge  co_ibge7         nm_municipio  \
# 269     100     11          Rondônia   110002   1100023            Ariquemes
# 56      130     11          Rondônia   110003   1100031               Cabixi
# 246     557     11          Rondônia   110011   1100114                 Jaru
# 226     895     11          Rondônia   110025   1100254    Presidente Médici
# 174    1102     11          Rondônia   110029   1100296  Santa Luzia D'Oeste
# ..      ...    ...               ...      ...       ...                  ...
# 210  289371     52             Goiás   522190   5221908               Varjão
# 277  289329     52             Goiás   522190   5221908               Varjão
# 105  289498     52             Goiás   522220   5222203             Vila Boa
# 214  289581     52             Goiás   522230   5222302        Vila Propício
# 26   289589     53  Distrito Federal   530010   5300108             Brasília
#
# ...

# %%
inf_df[inf_df.co_ibge7 == 2916401][['co_uf', 'nm_uf', 'nm_municipio',
       'atend_ivas', 'atend_totais', 'ano', 'epiweek', 
       'year_week_ts', 'ra_atend_ivas', 'ra_atend_ivas_ma',
       'gr_ra_atend_ivas_ma',  'tseries',
       'evi_t1_t', 'mu', 'ind', 'ind2', 'exc']]
# Out:
# Empty DataFrame
# Columns: [co_uf, nm_uf, nm_municipio, atend_ivas, atend_totais, ano, epiweek, year_week_ts, ra_atend_ivas, ra_atend_ivas_ma, gr_ra_atend_ivas_ma, tseries, evi_t1_t, mu, ind, ind2, exc]
# Index: []

# %%
df_final[(df_final.co_ibge7 == 2916401) & (df_final.ano ==2021)][['co_uf', 'nm_uf', 'nm_municipio',
       'atend_ivas', 'atend_totais', 'ano', 'epiweek', 
       'year_week_ts', 'ra_atend_ivas', 'ra_atend_ivas_ma',
       'gr_ra_atend_ivas_ma',  'tseries',
       'evi_t1_t', 'mu', 'ind', 'ind2', 'exc']]
# Out:
#      co_uf  nm_uf nm_municipio  atend_ivas  atend_totais   ano  epiweek  \
# 209     29  Bahia   Itapetinga           1            34  2021        1
# 210     29  Bahia   Itapetinga           1            48  2021        2
# 211     29  Bahia   Itapetinga          56           418  2021        3
# 212     29  Bahia   Itapetinga          36           381  2021        4
# 213     29  Bahia   Itapetinga          13           416  2021        5
# 214     29  Bahia   Itapetinga          32           450  2021        6
# 215     29  Bahia   Itapetinga          35           360  2021        7
# 216     29  Bahia   Itapetinga          24           582  2021        8
# 217     29  Bahia   Itapetinga          27           418  2021        9
# 218     29  Bahia   Itapetinga          28           443  2021       10
# 219     29  Bahia   Itapetinga          15           341  2021       11
# 220     29  Bahia   Itapetinga          24           362  2021       12
# ...

# %% [markdown]
# ## Analysis of model results

# %%
code = 2916401
df_final[(df_final.evi_t1_t <= 0) & (df_final.exc > 0)].co_ibge7.unique() # & (df_final.co_ibge7 == code)]
# Out:
# array([1100015, 1100023, 1100031, ..., 5222203, 5222302, 5300108])

# %%
code = 1100015
df_final[(df_final.evi_t1_t <= 0) & (df_final.exc > 0)  & (df_final.co_ibge7 == code)]
# Out:
#      index  co_uf     nm_uf  co_ibge  co_ibge7           nm_municipio  \
# 0       27     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 1       15     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 2       21     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 3       18     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 4       16     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# ..     ...    ...       ...      ...       ...                    ...
# 334     25     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 335      5     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 337     45     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 339     34     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
# 349     32     11  Rondônia   110001   1100015  Alta Floresta D'Oeste
#
#      atend_ivas  atend_totais   ano  epiweek  ... ra_atend_ivas_ma  \
# ...

# %%
dta_teste = df_final[df_final.co_ibge7 == code][['atend_ivas', 'tseries', 'epiweek', 'year_week',
       'year_week_ts', 
       'evi_t1_t', 'mu', 'ind',  'exc']][-20:]

# %%
dtf = dta_teste
x = dtf.epiweek#year_week_ts
fig = plt.figure(figsize =(15, 3))
plt.plot(x, dtf.atend_ivas)
plt.plot(x, dtf.tseries,'-o')
plt.plot(x, dtf.mu,linestyle = '--',label = 'mu')
#plt.plot(x, 0.75*dtf.mu,linestyle = '--',label = '0.75mu')
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()

# %%
dta_teste
# Out:
#      atend_ivas  tseries  epiweek year_week year_week_ts  evi_t1_t     mu  \
# 339          92     91.0       27   2023-27   2023-07-03     -0.39  104.0
# 340         112    102.0       28   2023-28   2023-07-10     -0.25  100.0
# 341          98    105.0       29   2023-29   2023-07-17      0.25   96.0
# 342          75     86.5       30   2023-30   2023-07-24     -0.17   88.0
# 343          89     82.0       31   2023-31   2023-07-31     -0.16   88.0
# 344          89     89.0       32   2023-32   2023-08-07      0.02   88.0
# 345          84     86.5       33   2023-33   2023-08-14     -0.12   91.0
# 346         106     95.0       34   2023-34   2023-08-21     -0.46   93.0
# 347          98    102.0       35   2023-35   2023-08-28      0.64   94.0
# 348          45     71.5       36   2023-36   2023-09-04      0.46   86.0
# 349          84     64.5       37   2023-37   2023-09-11      0.38   84.0
# 350          51     67.5       38   2023-38   2023-09-18      0.09   81.0
# ...

# %% [markdown]
# # Replace inf values in df_final

# %%
max_value = np.nanmax(df_final['evi_t1_t'][df_final['evi_t1_t'] != np.inf])

max_value
# Out:
# 212.41

# %%
df_final['evi_t1_t'].replace([np.inf, -np.inf], max_value, inplace=True)

# %%
df_final[(df_final == np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [index, co_uf, nm_uf, co_ibge, co_ibge7, nm_municipio, atend_ivas, atend_totais, ano, epiweek, year_week, year_week_ts, ra_atend_ivas, ra_atend_ivas_ma, gr_ra_atend_ivas_ma, ma_atend_indicators, pop, tseries, evi_t1_t, mu, ind, ind2, exc]
# Index: []
#
# [0 rows x 23 columns]

# %%
table = pa.Table.from_pandas(df_final)

lin = '/opt/storage/refined/aesop/visualization/PHC/2017_20230910_AESOP_variables2_mod.parquet'


pq.write_table(table, lin)
