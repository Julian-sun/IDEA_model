# %%
import pandas as pd

# %% [markdown]
# # PART 1 of MEM output

# %%
df = pd.read_parquet('/Users/julianeoliveira/Documents/Projects/AESOP/Artigo Classification/results/mem_output_29_09_25.parquet')

# %%
df.r_j_estr.describe()
# Out:
# count    22280.000000
# mean        17.472935
# std          7.760936
# min          0.000000
# 25%         12.000000
# 50%         18.000000
# 75%         23.000000
# max         52.000000
# Name: r_j_estr, dtype: float64

# %%
df[df.r_j_estr <= 3].co_ibge.nunique()
# Out:
# 1363

# %%
df[df.r_j_estr <= 0]
# Out:
#     epiyear  r_j_estr  k_start  k_end  co_ibge   low_level  medium_level  \
# 0      2022         0        1      0   110002  106.908106    127.896472
# 0      2022         0        1      0   110005   38.674297     62.814177
# 0      2022         0        1      0   110007   15.068420     29.969752
# 1      2023         0        1      0   110009  136.893126    517.503105
# 1      2023         0        1      0   110010   91.986466    178.396951
# ..      ...       ...      ...    ...      ...         ...           ...
# 0      2022         0        1      0   522108   12.206329     19.308670
# 3      2025         0        1      0   522130         NaN           NaN
# 0      2022         0        1      0   522140  277.544970    370.811248
# 0      2022         0        1      0   522145   50.715491     88.694962
# 1      2023         0        1      0   522190    6.374379     10.945823
#
#     high_level    baseline  epidemic_threshold
# ...

# %%
df[(df.k_start == 1) & (df.r_j_estr == 0)].co_ibge.unique()
# Out:
# array([110002, 110005, 110007, ..., 522140, 522145, 522190], dtype=int32)

# %%
df[df.co_ibge == 110002]
# Out:
#    epiyear  r_j_estr  k_start  k_end  co_ibge   low_level  medium_level  \
# 0     2022         0        1      0   110002  106.908106    127.896472
# 1     2023        17       10     26   110002  106.908106    127.896472
# 2     2024        24        3     26   110002  106.908106    127.896472
# 3     2025        26        1     26   110002  106.908106    127.896472
#
#    high_level  baseline  epidemic_threshold
# 0   134.56353      60.0           87.704546
# 1   134.56353      60.0           87.704546
# 2   134.56353      60.0           87.704546
# 3   134.56353      60.0           87.704546
